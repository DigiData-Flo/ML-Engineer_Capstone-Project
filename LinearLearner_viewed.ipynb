# %% [markdown]
# # ML Model with LinearLearner

# %%
import os

import time
from time import gmtime, strftime

import pandas as pd
import numpy as np
import math
import json
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## Import the preprocessed data

# %%
features = pd.read_csv('data/features_viewed.csv', index_col=0)
labels = pd.read_csv('data/labels_viewed.csv', index_col=0)

# %%
features.shape, labels.shape
# Out:
# ((63288, 10), (63288, 1))

# %% [markdown]
# ## Create Sagemaker items

# %%
import sagemaker

# %%
# sagemaker session, role
sagemaker_session = sagemaker.Session()
role = sagemaker.get_execution_role()

# S3 bucket name
bucket = sagemaker_session.default_bucket()

# %% [markdown]
# ## Create Training, Validation and Testdata
# To avoid overfitting I split the train data additional in validation data.

# %%
from sklearn.model_selection import train_test_split

# %%
# We split the dataset into 2/3 training and 1/3 testing sets.
X_train, X_test, Y_train, Y_test = train_test_split(features, labels, test_size=0.33)

# %%
# import LinearLearner
from sagemaker import LinearLearner

# specify an output path
prefix = 'capstone/viewed/ll'
output_path = 's3://{}/{}'.format(bucket, prefix)

# instantiate LinearLearner
linear = LinearLearner(role=role,
                       instance_count=1, 
                       instance_type='ml.m4.xlarge',
                       predictor_type='binary_classifier',
                       output_path=output_path,
                       sagemaker_session=sagemaker_session,
                       epochs=15)

# %%
# convert features/labels to numpy
train_x_np = features.values.astype('float32')
train_y_np = labels.values.astype('float32').flatten()

train_x_np
train_y_np
# Out:
# array([1., 1., 1., ..., 0., 0., 0.], dtype=float32)

# %%
# convert features/labels to numpy
train_x_np = features.values.astype('float32')
train_y_np = labels.values.astype('float32').flatten()


#type(train_x_np)
# create RecordSet
formatted_train_data = linear.record_set(train_x_np, labels=train_y_np)

# %%
# %%time 
# train the estimator on formatted training data
linear.fit(formatted_train_data)
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2021-10-05 07:05:32 Starting - Starting the training job...
# 2021-10-05 07:05:56 Starting - Launching requested ML instancesProfilerReport-1633417532: InProgress
# ...
# 2021-10-05 07:06:23 Starting - Preparing the instances for training.........
# 2021-10-05 07:07:56 Downloading - Downloading input data...
# 2021-10-05 07:08:22 Training - Downloading the training image..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [10/05/2021 07:08:46 INFO 140429084538688] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [10/05/2021 07:08:46 INFO 140429084538688] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '10', 'predictor_type': 'binary_classifier', 'epochs': '15', 'mini_batch_size': '1000'}
# [10/05/2021 07:08:46 INFO 140429084538688] Final configuration: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': '10', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'binary_classifier'}
# [10/05/2021 07:08:46 WARNING 140429084538688] Loggers have already been setup.
# Process 1 is a worker.
# [10/05/2021 07:08:46 INFO 140429084538688] Using default worker.
# [10/05/2021 07:08:46 INFO 140429084538688] Checkpoint loading and saving are disabled.
# [2021-10-05 07:08:46.991] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 20, "num_examples": 1, "num_bytes": 84000}
# [10/05/2021 07:08:46 INFO 140429084538688] Create Store: local
# [2021-10-05 07:08:47.115] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 123, "num_examples": 11, "num_bytes": 924000}
# [10/05/2021 07:08:47 INFO 140429084538688] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7fb7d0f38d10>
# [10/05/2021 07:08:47 INFO 140429084538688] Scaling model computed with parameters:
#  {'stdev_label': None, 'stdev_weight':
# [0.1967722  0.22458509 1.         1.         1.         1.
#  0.4781814  0.49995947 0.10847703 0.33388722]
# <NDArray 10 @cpu(0)>, 'mean_label': None, 'mean_weight':
# [0.4381745  0.39306915 1.         1.         1.         1.
#  0.3539091  0.5063637  0.01190909 0.1278182 ]
# <NDArray 10 @cpu(0)>}
# [10/05/2021 07:08:47 INFO 140429084538688] nvidia-smi: took 0.031 seconds to run.
# [10/05/2021 07:08:47 INFO 140429084538688] nvidia-smi identified 0 GPUs.
# [10/05/2021 07:08:47 INFO 140429084538688] Number of GPUs being used: 0
# #metrics {"StartTime": 1633417727.2276697, "EndTime": 1633417727.2277067, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 12000.0, "count": 1, "min": 12000, "max": 12000}, "Total Batches Seen": {"sum": 12.0, "count": 1, "min": 12, "max": 12}, "Max Records Seen Between Resets": {"sum": 11000.0, "count": 1, "min": 11000, "max": 11000}, "Max Batches Seen Between Resets": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [2021-10-05 07:08:49.691] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 2462, "num_examples": 64, "num_bytes": 5316192}
# #metrics {"StartTime": 1633417729.691103, "EndTime": 1633417729.6912084, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5965424867660281, "count": 1, "min": 0.5965424867660281, "max": 0.5965424867660281}}}
#
# #metrics {"StartTime": 1633417729.6913185, "EndTime": 1633417729.6913397, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5963440469408792, "count": 1, "min": 0.5963440469408792, "max": 0.5963440469408792}}}
#
# #metrics {"StartTime": 1633417729.6913939, "EndTime": 1633417729.6914093, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5973339456225198, "count": 1, "min": 0.5973339456225198, "max": 0.5973339456225198}}}
#
# #metrics {"StartTime": 1633417729.6914597, "EndTime": 1633417729.691474, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.596496346609933, "count": 1, "min": 0.596496346609933, "max": 0.596496346609933}}}
#
# #metrics {"StartTime": 1633417729.6915243, "EndTime": 1633417729.6915412, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7109897934444367, "count": 1, "min": 0.7109897934444367, "max": 0.7109897934444367}}}
#
# #metrics {"StartTime": 1633417729.691603, "EndTime": 1633417729.6916206, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7138444738236684, "count": 1, "min": 0.7138444738236684, "max": 0.7138444738236684}}}
#
# #metrics {"StartTime": 1633417729.6916819, "EndTime": 1633417729.691699, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.70480492316352, "count": 1, "min": 0.70480492316352, "max": 0.70480492316352}}}
#
# #metrics {"StartTime": 1633417729.6917515, "EndTime": 1633417729.6917686, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7097518405006046, "count": 1, "min": 0.7097518405006046, "max": 0.7097518405006046}}}
#
# #metrics {"StartTime": 1633417729.6918223, "EndTime": 1633417729.6918385, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.596346183171348, "count": 1, "min": 0.596346183171348, "max": 0.596346183171348}}}
#
# #metrics {"StartTime": 1633417729.6918886, "EndTime": 1633417729.6919045, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5976166255890377, "count": 1, "min": 0.5976166255890377, "max": 0.5976166255890377}}}
#
# #metrics {"StartTime": 1633417729.6919527, "EndTime": 1633417729.6919682, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5982295992412264, "count": 1, "min": 0.5982295992412264, "max": 0.5982295992412264}}}
#
# #metrics {"StartTime": 1633417729.6920228, "EndTime": 1633417729.6920404, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5974210355243985, "count": 1, "min": 0.5974210355243985, "max": 0.5974210355243985}}}
#
# #metrics {"StartTime": 1633417729.6920962, "EndTime": 1633417729.6921132, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7061216123066252, "count": 1, "min": 0.7061216123066252, "max": 0.7061216123066252}}}
#
# #metrics {"StartTime": 1633417729.692166, "EndTime": 1633417729.6921835, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7022153112017919, "count": 1, "min": 0.7022153112017919, "max": 0.7022153112017919}}}
#
# #metrics {"StartTime": 1633417729.6922731, "EndTime": 1633417729.6922925, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7072439973619249, "count": 1, "min": 0.7072439973619249, "max": 0.7072439973619249}}}
#
# #metrics {"StartTime": 1633417729.692346, "EndTime": 1633417729.692363, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.703268935793922, "count": 1, "min": 0.703268935793922, "max": 0.703268935793922}}}
#
# #metrics {"StartTime": 1633417729.6924245, "EndTime": 1633417729.6924436, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5982453753758991, "count": 1, "min": 0.5982453753758991, "max": 0.5982453753758991}}}
#
# #metrics {"StartTime": 1633417729.69251, "EndTime": 1633417729.6925285, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.598935526529948, "count": 1, "min": 0.598935526529948, "max": 0.598935526529948}}}
#
# #metrics {"StartTime": 1633417729.6925936, "EndTime": 1633417729.6926117, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5977697942824591, "count": 1, "min": 0.5977697942824591, "max": 0.5977697942824591}}}
#
# #metrics {"StartTime": 1633417729.6926672, "EndTime": 1633417729.6926842, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6000919063507565, "count": 1, "min": 0.6000919063507565, "max": 0.6000919063507565}}}
#
# #metrics {"StartTime": 1633417729.6927452, "EndTime": 1633417729.692762, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6744719533768911, "count": 1, "min": 0.6744719533768911, "max": 0.6744719533768911}}}
#
# #metrics {"StartTime": 1633417729.692821, "EndTime": 1633417729.692838, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6682697601318359, "count": 1, "min": 0.6682697601318359, "max": 0.6682697601318359}}}
#
# #metrics {"StartTime": 1633417729.6929023, "EndTime": 1633417729.6929207, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6734582186502124, "count": 1, "min": 0.6734582186502124, "max": 0.6734582186502124}}}
#
# #metrics {"StartTime": 1633417729.692984, "EndTime": 1633417729.6930015, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6691096587408156, "count": 1, "min": 0.6691096587408156, "max": 0.6691096587408156}}}
#
# #metrics {"StartTime": 1633417729.6930535, "EndTime": 1633417729.6930692, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6060143180726066, "count": 1, "min": 0.6060143180726066, "max": 0.6060143180726066}}}
#
# #metrics {"StartTime": 1633417729.6931198, "EndTime": 1633417729.6931355, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6061426386757502, "count": 1, "min": 0.6061426386757502, "max": 0.6061426386757502}}}
#
# #metrics {"StartTime": 1633417729.6931865, "EndTime": 1633417729.6932027, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6059163668193515, "count": 1, "min": 0.6059163668193515, "max": 0.6059163668193515}}}
#
# #metrics {"StartTime": 1633417729.6932533, "EndTime": 1633417729.693269, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6061016031901042, "count": 1, "min": 0.6061016031901042, "max": 0.6061016031901042}}}
#
# #metrics {"StartTime": 1633417729.6933222, "EndTime": 1633417729.6933393, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7275049471173968, "count": 1, "min": 0.7275049471173968, "max": 0.7275049471173968}}}
#
# #metrics {"StartTime": 1633417729.6933928, "EndTime": 1633417729.693408, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7263018961104135, "count": 1, "min": 0.7263018961104135, "max": 0.7263018961104135}}}
#
# #metrics {"StartTime": 1633417729.6934588, "EndTime": 1633417729.693474, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.726523695688399, "count": 1, "min": 0.726523695688399, "max": 0.726523695688399}}}
#
# #metrics {"StartTime": 1633417729.693522, "EndTime": 1633417729.6935344, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7274139830574157, "count": 1, "min": 0.7274139830574157, "max": 0.7274139830574157}}}
#
# [10/05/2021 07:08:49 INFO 140429084538688] #quality_metric: host=algo-1, epoch=0, train binary_classification_cross_entropy_objective <loss>=0.5965424867660281
# [10/05/2021 07:08:49 INFO 140429084538688] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_cross_entropy_objective, value=0.5963440469408792
# [10/05/2021 07:08:49 INFO 140429084538688] Epoch 0: Loss improved. Updating best model
# [10/05/2021 07:08:49 INFO 140429084538688] Saving model for epoch: 0
# [10/05/2021 07:08:49 INFO 140429084538688] Saved checkpoint to "/tmp/tmp8qniinrt/mx-mod-0000.params"
# [10/05/2021 07:08:49 INFO 140429084538688] #progress_metric: host=algo-1, completed 6.666666666666667 % of epochs
# #metrics {"StartTime": 1633417727.2280297, "EndTime": 1633417729.710672, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 75288.0, "count": 1, "min": 75288, "max": 75288}, "Total Batches Seen": {"sum": 76.0, "count": 1, "min": 76, "max": 76}, "Max Records Seen Between Resets": {"sum": 63288.0, "count": 1, "min": 63288, "max": 63288}, "Max Batches Seen Between Resets": {"sum": 64.0, "count": 1, "min": 64, "max": 64}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 63288.0, "count": 1, "min": 63288, "max": 63288}, "Number of Batches Since Last Reset": {"sum": 64.0, "count": 1, "min": 64, "max": 64}}}
#
# [10/05/2021 07:08:49 INFO 140429084538688] #throughput_metric: host=algo-1, train throughput=25490.60446035696 records/second
#
# 2021-10-05 07:08:57 Training - Training image download completed. Training in progress.[2021-10-05 07:08:52.283] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 2571, "num_examples": 64, "num_bytes": 5316192}
# #metrics {"StartTime": 1633417732.2833796, "EndTime": 1633417732.2836869, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5378193572513641, "count": 1, "min": 0.5378193572513641, "max": 0.5378193572513641}}}
#
# #metrics {"StartTime": 1633417732.2837863, "EndTime": 1633417732.2838016, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5371949467734685, "count": 1, "min": 0.5371949467734685, "max": 0.5371949467734685}}}
#
# #metrics {"StartTime": 1633417732.2838428, "EndTime": 1633417732.2838573, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5387786303323413, "count": 1, "min": 0.5387786303323413, "max": 0.5387786303323413}}}
#
# #metrics {"StartTime": 1633417732.2839072, "EndTime": 1633417732.2839224, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5375409807477679, "count": 1, "min": 0.5375409807477679, "max": 0.5375409807477679}}}
#
# #metrics {"StartTime": 1633417732.2839735, "EndTime": 1633417732.283985, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6855189034598215, "count": 1, "min": 0.6855189034598215, "max": 0.6855189034598215}}}
#
# #metrics {"StartTime": 1633417732.2840378, "EndTime": 1633417732.284054, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6871943514384921, "count": 1, "min": 0.6871943514384921, "max": 0.6871943514384921}}}
#
# #metrics {"StartTime": 1633417732.284117, "EndTime": 1633417732.284135, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6846518152630519, "count": 1, "min": 0.6846518152630519, "max": 0.6846518152630519}}}
#
# #metrics {"StartTime": 1633417732.2841914, "EndTime": 1633417732.2842345, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6870678129650297, "count": 1, "min": 0.6870678129650297, "max": 0.6870678129650297}}}
#
# #metrics {"StartTime": 1633417732.284295, "EndTime": 1633417732.2843134, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5375656360444568, "count": 1, "min": 0.5375656360444568, "max": 0.5375656360444568}}}
#
# #metrics {"StartTime": 1633417732.2843692, "EndTime": 1633417732.284385, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5388385765438988, "count": 1, "min": 0.5388385765438988, "max": 0.5388385765438988}}}
#
# #metrics {"StartTime": 1633417732.2844408, "EndTime": 1633417732.284457, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5399410017709884, "count": 1, "min": 0.5399410017709884, "max": 0.5399410017709884}}}
#
# #metrics {"StartTime": 1633417732.2845218, "EndTime": 1633417732.2845378, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5388453083341084, "count": 1, "min": 0.5388453083341084, "max": 0.5388453083341084}}}
#
# #metrics {"StartTime": 1633417732.2846026, "EndTime": 1633417732.2846193, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6461661444769965, "count": 1, "min": 0.6461661444769965, "max": 0.6461661444769965}}}
#
# #metrics {"StartTime": 1633417732.2846744, "EndTime": 1633417732.2846918, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6349763830275763, "count": 1, "min": 0.6349763830275763, "max": 0.6349763830275763}}}
#
# #metrics {"StartTime": 1633417732.2847567, "EndTime": 1633417732.284775, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6443788854205419, "count": 1, "min": 0.6443788854205419, "max": 0.6443788854205419}}}
#
# #metrics {"StartTime": 1633417732.284839, "EndTime": 1633417732.2848551, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6353590780591207, "count": 1, "min": 0.6353590780591207, "max": 0.6353590780591207}}}
#
# #metrics {"StartTime": 1633417732.2849128, "EndTime": 1633417732.2849302, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5643178211999318, "count": 1, "min": 0.5643178211999318, "max": 0.5643178211999318}}}
#
# #metrics {"StartTime": 1633417732.2849877, "EndTime": 1633417732.2850041, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5657549680679563, "count": 1, "min": 0.5657549680679563, "max": 0.5657549680679563}}}
#
# #metrics {"StartTime": 1633417732.2850647, "EndTime": 1633417732.2850811, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5643709610227554, "count": 1, "min": 0.5643709610227554, "max": 0.5643709610227554}}}
#
# #metrics {"StartTime": 1633417732.2851362, "EndTime": 1633417732.2851527, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5656441083635603, "count": 1, "min": 0.5656441083635603, "max": 0.5656441083635603}}}
#
# #metrics {"StartTime": 1633417732.2852142, "EndTime": 1633417732.2852309, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.67226734003945, "count": 1, "min": 0.67226734003945, "max": 0.67226734003945}}}
#
# #metrics {"StartTime": 1633417732.285286, "EndTime": 1633417732.2853029, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6568949661254883, "count": 1, "min": 0.6568949661254883, "max": 0.6568949661254883}}}
#
# #metrics {"StartTime": 1633417732.2853646, "EndTime": 1633417732.2853832, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6715675183250791, "count": 1, "min": 0.6715675183250791, "max": 0.6715675183250791}}}
#
# #metrics {"StartTime": 1633417732.285445, "EndTime": 1633417732.2854626, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6583538086906312, "count": 1, "min": 0.6583538086906312, "max": 0.6583538086906312}}}
#
# #metrics {"StartTime": 1633417732.28552, "EndTime": 1633417732.2855358, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5753058893112909, "count": 1, "min": 0.5753058893112909, "max": 0.5753058893112909}}}
#
# #metrics {"StartTime": 1633417732.2855957, "EndTime": 1633417732.2856126, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5770460728236607, "count": 1, "min": 0.5770460728236607, "max": 0.5770460728236607}}}
#
# #metrics {"StartTime": 1633417732.2856705, "EndTime": 1633417732.285685, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5752879817902096, "count": 1, "min": 0.5752879817902096, "max": 0.5752879817902096}}}
#
# #metrics {"StartTime": 1633417732.2857401, "EndTime": 1633417732.2857547, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5769108460441468, "count": 1, "min": 0.5769108460441468, "max": 0.5769108460441468}}}
#
# #metrics {"StartTime": 1633417732.285813, "EndTime": 1633417732.2858295, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7550067361498636, "count": 1, "min": 0.7550067361498636, "max": 0.7550067361498636}}}
#
# #metrics {"StartTime": 1633417732.285888, "EndTime": 1633417732.2859046, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7644070492699033, "count": 1, "min": 0.7644070492699033, "max": 0.7644070492699033}}}
#
# #metrics {"StartTime": 1633417732.2859566, "EndTime": 1633417732.2859733, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7548097872052874, "count": 1, "min": 0.7548097872052874, "max": 0.7548097872052874}}}
#
# #metrics {"StartTime": 1633417732.2860367, "EndTime": 1633417732.2860541, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7649501628572979, "count": 1, "min": 0.7649501628572979, "max": 0.7649501628572979}}}
#
# [10/05/2021 07:08:52 INFO 140429084538688] #quality_metric: host=algo-1, epoch=1, train binary_classification_cross_entropy_objective <loss>=0.5378193572513641
# [10/05/2021 07:08:52 INFO 140429084538688] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_cross_entropy_objective, value=0.5371949467734685
# [10/05/2021 07:08:52 INFO 140429084538688] Epoch 1: Loss improved. Updating best model
# [10/05/2021 07:08:52 INFO 140429084538688] Saving model for epoch: 1
# [10/05/2021 07:08:52 INFO 140429084538688] Saved checkpoint to "/tmp/tmpmh2uhdr0/mx-mod-0000.params"
# [10/05/2021 07:08:52 INFO 140429084538688] #progress_metric: host=algo-1, completed 13.333333333333334 % of epochs
# #metrics {"StartTime": 1633417729.7112598, "EndTime": 1633417732.2986598, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 138576.0, "count": 1, "min": 138576, "max": 138576}, "Total Batches Seen": {"sum": 140.0, "count": 1, "min": 140, "max": 140}, "Max Records Seen Between Resets": {"sum": 63288.0, "count": 1, "min": 63288, "max": 63288}, "Max Batches Seen Between Resets": {"sum": 64.0, "count": 1, "min": 64, "max": 64}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 63288.0, "count": 1, "min": 63288, "max": 63288}, "Number of Batches Since Last Reset": {"sum": 64.0, "count": 1, "min": 64, "max": 64}}}
#
# [10/05/2021 07:08:52 INFO 140429084538688] #throughput_metric: host=algo-1, train throughput=24458.672035890653 records/second
# [2021-10-05 07:08:54.734] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 7, "duration": 2435, "num_examples": 64, "num_bytes": 5316192}
# #metrics {"StartTime": 1633417734.7345538, "EndTime": 1633417734.734641, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5151241057865203, "count": 1, "min": 0.5151241057865203, "max": 0.5151241057865203}}}
#
# #metrics {"StartTime": 1633417734.734728, "EndTime": 1633417734.7347455, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5135280437166728, "count": 1, "min": 0.5135280437166728, "max": 0.5135280437166728}}}
#
# #metrics {"StartTime": 1633417734.7348068, "EndTime": 1633417734.734824, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5159606071351066, "count": 1, "min": 0.5159606071351066, "max": 0.5159606071351066}}}
#
# #metrics {"StartTime": 1633417734.734884, "EndTime": 1633417734.7349002, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5138756563701327, "count": 1, "min": 0.5138756563701327, "max": 0.5138756563701327}}}
#
# #metrics {"StartTime": 1633417734.734953, "EndTime": 1633417734.73497, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5013667340959821, "count": 1, "min": 0.5013667340959821, "max": 0.5013667340959821}}}
#
# #metrics {"StartTime": 1633417734.7350209, "EndTime": 1633417734.735036, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5305478950379386, "count": 1, "min": 0.5305478950379386, "max": 0.5305478950379386}}}
#
# #metrics {"StartTime": 1633417734.735089, "EndTime": 1633417734.7351053, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5018793347071088, "count": 1, "min": 0.5018793347071088, "max": 0.5018793347071088}}}
#
# #metrics {"StartTime": 1633417734.7351582, "EndTime": 1633417734.7351751, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5325785258459667, "count": 1, "min": 0.5325785258459667, "max": 0.5325785258459667}}}
#
# #metrics {"StartTime": 1633417734.7352312, "EndTime": 1633417734.7352479, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5156082192072793, "count": 1, "min": 0.5156082192072793, "max": 0.5156082192072793}}}
#
# #metrics {"StartTime": 1633417734.7353148, "EndTime": 1633417734.735332, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5157630760556176, "count": 1, "min": 0.5157630760556176, "max": 0.5157630760556176}}}
#
# #metrics {"StartTime": 1633417734.7354014, "EndTime": 1633417734.7354198, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5176939818367126, "count": 1, "min": 0.5176939818367126, "max": 0.5176939818367126}}}
#
# #metrics {"StartTime": 1633417734.7354891, "EndTime": 1633417734.735507, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5157665218777127, "count": 1, "min": 0.5157665218777127, "max": 0.5157665218777127}}}
#
# #metrics {"StartTime": 1633417734.735573, "EndTime": 1633417734.735591, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4998759258209713, "count": 1, "min": 0.4998759258209713, "max": 0.4998759258209713}}}
#
# #metrics {"StartTime": 1633417734.7356436, "EndTime": 1633417734.7356603, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5106934353056408, "count": 1, "min": 0.5106934353056408, "max": 0.5106934353056408}}}
#
# #metrics {"StartTime": 1633417734.7357152, "EndTime": 1633417734.7357304, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4992699145362491, "count": 1, "min": 0.4992699145362491, "max": 0.4992699145362491}}}
#
# #metrics {"StartTime": 1633417734.735783, "EndTime": 1633417734.7357996, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5102236684163411, "count": 1, "min": 0.5102236684163411, "max": 0.5102236684163411}}}
#
# #metrics {"StartTime": 1633417734.735849, "EndTime": 1633417734.735863, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5615525924440414, "count": 1, "min": 0.5615525924440414, "max": 0.5615525924440414}}}
#
# #metrics {"StartTime": 1633417734.7359116, "EndTime": 1633417734.7359283, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5644114331442213, "count": 1, "min": 0.5644114331442213, "max": 0.5644114331442213}}}
#
# #metrics {"StartTime": 1633417734.7359824, "EndTime": 1633417734.7359986, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.561568599155971, "count": 1, "min": 0.561568599155971, "max": 0.561568599155971}}}
#
# #metrics {"StartTime": 1633417734.736053, "EndTime": 1633417734.736068, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5643363613552518, "count": 1, "min": 0.5643363613552518, "max": 0.5643363613552518}}}
#
# #metrics {"StartTime": 1633417734.7361307, "EndTime": 1633417734.7361488, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6918299214196584, "count": 1, "min": 0.6918299214196584, "max": 0.6918299214196584}}}
#
# #metrics {"StartTime": 1633417734.7362344, "EndTime": 1633417734.7362466, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.681728384714278, "count": 1, "min": 0.681728384714278, "max": 0.681728384714278}}}
#
# #metrics {"StartTime": 1633417734.7362843, "EndTime": 1633417734.7362955, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6917548773629325, "count": 1, "min": 0.6917548773629325, "max": 0.6917548773629325}}}
#
# #metrics {"StartTime": 1633417734.7363472, "EndTime": 1633417734.7363641, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6826168868049742, "count": 1, "min": 0.6826168868049742, "max": 0.6826168868049742}}}
#
# #metrics {"StartTime": 1633417734.736429, "EndTime": 1633417734.7364466, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5733853459433904, "count": 1, "min": 0.5733853459433904, "max": 0.5733853459433904}}}
#
# #metrics {"StartTime": 1633417734.7364883, "EndTime": 1633417734.7364986, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5765274009099083, "count": 1, "min": 0.5765274009099083, "max": 0.5765274009099083}}}
#
# #metrics {"StartTime": 1633417734.7365294, "EndTime": 1633417734.736544, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.573338392469618, "count": 1, "min": 0.573338392469618, "max": 0.573338392469618}}}
#
# #metrics {"StartTime": 1633417734.7366025, "EndTime": 1633417734.7366197, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.576441658625527, "count": 1, "min": 0.576441658625527, "max": 0.576441658625527}}}
#
# #metrics {"StartTime": 1633417734.73668, "EndTime": 1633417734.7366974, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7119571806892516, "count": 1, "min": 0.7119571806892516, "max": 0.7119571806892516}}}
#
# #metrics {"StartTime": 1633417734.7367578, "EndTime": 1633417734.7367747, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7291925110589891, "count": 1, "min": 0.7291925110589891, "max": 0.7291925110589891}}}
#
# #metrics {"StartTime": 1633417734.736834, "EndTime": 1633417734.7368505, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7119352653140113, "count": 1, "min": 0.7119352653140113, "max": 0.7119352653140113}}}
#
# #metrics {"StartTime": 1633417734.736901, "EndTime": 1633417734.7369173, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7290309709821429, "count": 1, "min": 0.7290309709821429, "max": 0.7290309709821429}}}
#
# [10/05/2021 07:08:54 INFO 140429084538688] #quality_metric: host=algo-1, epoch=2, train binary_classification_cross_entropy_objective <loss>=0.5151241057865203
# [10/05/2021 07:08:54 INFO 140429084538688] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_cross_entropy_objective, value=0.4992699145362491
# [10/05/2021 07:08:54 INFO 140429084538688] Epoch 2: Loss improved. Updating best model
# [10/05/2021 07:08:54 INFO 140429084538688] Saving model for epoch: 2
# [10/05/2021 07:08:54 INFO 140429084538688] Saved checkpoint to "/tmp/tmp5yy873en/mx-mod-0000.params"
# [10/05/2021 07:08:54 INFO 140429084538688] #progress_metric: host=algo-1, completed 20.0 % of epochs
# #metrics {"StartTime": 1633417732.2993076, "EndTime": 1633417734.74753, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 201864.0, "count": 1, "min": 201864, "max": 201864}, "Total Batches Seen": {"sum": 204.0, "count": 1, "min": 204, "max": 204}, "Max Records Seen Between Resets": {"sum": 63288.0, "count": 1, "min": 63288, "max": 63288}, "Max Batches Seen Between Resets": {"sum": 64.0, "count": 1, "min": 64, "max": 64}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 63288.0, "count": 1, "min": 63288, "max": 63288}, "Number of Batches Since Last Reset": {"sum": 64.0, "count": 1, "min": 64, "max": 64}}}
#
# [10/05/2021 07:08:54 INFO 140429084538688] #throughput_metric: host=algo-1, train throughput=25848.98412538898 records/second
# [2021-10-05 07:08:56.945] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 9, "duration": 2197, "num_examples": 64, "num_bytes": 5316192}
# #metrics {"StartTime": 1633417736.9456735, "EndTime": 1633417736.9457664, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.498885002015129, "count": 1, "min": 0.498885002015129, "max": 0.498885002015129}}}
#
# #metrics {"StartTime": 1633417736.945868, "EndTime": 1633417736.94589, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4959599122546968, "count": 1, "min": 0.4959599122546968, "max": 0.4959599122546968}}}
#
# #metrics {"StartTime": 1633417736.9459503, "EndTime": 1633417736.945968, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.49962552703373014, "count": 1, "min": 0.49962552703373014, "max": 0.49962552703373014}}}
#
# #metrics {"StartTime": 1633417736.9460273, "EndTime": 1633417736.946046, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4962997911241319, "count": 1, "min": 0.4962997911241319, "max": 0.4962997911241319}}}
#
# #metrics {"StartTime": 1633417736.946108, "EndTime": 1633417736.9461267, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.44827560582236636, "count": 1, "min": 0.44827560582236636, "max": 0.44827560582236636}}}
#
# #metrics {"StartTime": 1633417736.9461858, "EndTime": 1633417736.9462035, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.46052942814902653, "count": 1, "min": 0.46052942814902653, "max": 0.46052942814902653}}}
#
# #metrics {"StartTime": 1633417736.9462585, "EndTime": 1633417736.9462743, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4489280596536303, "count": 1, "min": 0.4489280596536303, "max": 0.4489280596536303}}}
#
# ...
#
# #metrics {"StartTime": 1633417762.369259, "EndTime": 1633417762.3692715, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4395858139764695, "count": 1, "min": 0.4395858139764695, "max": 0.4395858139764695}}}
#
# #metrics {"StartTime": 1633417762.3693135, "EndTime": 1633417762.3693252, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4305023622058687, "count": 1, "min": 0.4305023622058687, "max": 0.4305023622058687}}}
#
# #metrics {"StartTime": 1633417762.3693645, "EndTime": 1633417762.3693757, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.46173138863699775, "count": 1, "min": 0.46173138863699775, "max": 0.46173138863699775}}}
#
# #metrics {"StartTime": 1633417762.3694174, "EndTime": 1633417762.3694286, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.43046463836185517, "count": 1, "min": 0.43046463836185517, "max": 0.43046463836185517}}}
#
# #metrics {"StartTime": 1633417762.3694685, "EndTime": 1633417762.3694794, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4618667759971013, "count": 1, "min": 0.4618667759971013, "max": 0.4618667759971013}}}
#
# #metrics {"StartTime": 1633417762.369518, "EndTime": 1633417762.369529, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4305024202134874, "count": 1, "min": 0.4305024202134874, "max": 0.4305024202134874}}}
#
# #metrics {"StartTime": 1633417762.3695674, "EndTime": 1633417762.3695786, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.44451036410861544, "count": 1, "min": 0.44451036410861544, "max": 0.44451036410861544}}}
#
# #metrics {"StartTime": 1633417762.369618, "EndTime": 1633417762.369629, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4383968261234344, "count": 1, "min": 0.4383968261234344, "max": 0.4383968261234344}}}
#
# #metrics {"StartTime": 1633417762.3696692, "EndTime": 1633417762.3696802, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4451849539620536, "count": 1, "min": 0.4451849539620536, "max": 0.4451849539620536}}}
#
# #metrics {"StartTime": 1633417762.3697195, "EndTime": 1633417762.3697305, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.43839837791806174, "count": 1, "min": 0.43839837791806174, "max": 0.43839837791806174}}}
#
# #metrics {"StartTime": 1633417762.3697696, "EndTime": 1633417762.3697805, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.46513649507552857, "count": 1, "min": 0.46513649507552857, "max": 0.46513649507552857}}}
#
# #metrics {"StartTime": 1633417762.369819, "EndTime": 1633417762.36983, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.45815489366319445, "count": 1, "min": 0.45815489366319445, "max": 0.45815489366319445}}}
#
# #metrics {"StartTime": 1633417762.369868, "EndTime": 1633417762.3698788, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4651469441973974, "count": 1, "min": 0.4651469441973974, "max": 0.4651469441973974}}}
#
# #metrics {"StartTime": 1633417762.3699172, "EndTime": 1633417762.369928, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.458232189117916, "count": 1, "min": 0.458232189117916, "max": 0.458232189117916}}}
#
# #metrics {"StartTime": 1633417762.369966, "EndTime": 1633417762.3699768, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.550427482483879, "count": 1, "min": 0.550427482483879, "max": 0.550427482483879}}}
#
# #metrics {"StartTime": 1633417762.3700147, "EndTime": 1633417762.3700256, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5637127908373636, "count": 1, "min": 0.5637127908373636, "max": 0.5637127908373636}}}
#
# #metrics {"StartTime": 1633417762.370067, "EndTime": 1633417762.3700783, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5504283912295387, "count": 1, "min": 0.5504283912295387, "max": 0.5504283912295387}}}
#
# #metrics {"StartTime": 1633417762.370129, "EndTime": 1633417762.3701413, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5637055199032738, "count": 1, "min": 0.5637055199032738, "max": 0.5637055199032738}}}
#
# #metrics {"StartTime": 1633417762.3701835, "EndTime": 1633417762.3701944, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6118126571897476, "count": 1, "min": 0.6118126571897476, "max": 0.6118126571897476}}}
#
# #metrics {"StartTime": 1633417762.3702354, "EndTime": 1633417762.3702464, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6907004111153738, "count": 1, "min": 0.6907004111153738, "max": 0.6907004111153738}}}
#
# #metrics {"StartTime": 1633417762.3702877, "EndTime": 1633417762.3702989, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6118173030066112, "count": 1, "min": 0.6118173030066112, "max": 0.6118173030066112}}}
#
# #metrics {"StartTime": 1633417762.3703406, "EndTime": 1633417762.3703516, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6907083890400235, "count": 1, "min": 0.6907083890400235, "max": 0.6907083890400235}}}
#
# #metrics {"StartTime": 1633417762.3703973, "EndTime": 1633417762.3704095, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5618838966006324, "count": 1, "min": 0.5618838966006324, "max": 0.5618838966006324}}}
#
# #metrics {"StartTime": 1633417762.3704498, "EndTime": 1633417762.3704607, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.575683843703497, "count": 1, "min": 0.575683843703497, "max": 0.575683843703497}}}
#
# #metrics {"StartTime": 1633417762.370507, "EndTime": 1633417762.370517, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5618727615598649, "count": 1, "min": 0.5618727615598649, "max": 0.5618727615598649}}}
#
# #metrics {"StartTime": 1633417762.3705459, "EndTime": 1633417762.3705542, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5756207488529266, "count": 1, "min": 0.5756207488529266, "max": 0.5756207488529266}}}
#
# #metrics {"StartTime": 1633417762.3705857, "EndTime": 1633417762.3705945, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6194026008484855, "count": 1, "min": 0.6194026008484855, "max": 0.6194026008484855}}}
#
# #metrics {"StartTime": 1633417762.370622, "EndTime": 1633417762.3706298, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7180139476231167, "count": 1, "min": 0.7180139476231167, "max": 0.7180139476231167}}}
#
# #metrics {"StartTime": 1633417762.370656, "EndTime": 1633417762.370664, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6193855524214488, "count": 1, "min": 0.6193855524214488, "max": 0.6193855524214488}}}
#
# #metrics {"StartTime": 1633417762.3706899, "EndTime": 1633417762.370698, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.717974597749256, "count": 1, "min": 0.717974597749256, "max": 0.717974597749256}}}
#
# [10/05/2021 07:09:22 INFO 140429084538688] #quality_metric: host=algo-1, epoch=14, train binary_classification_cross_entropy_objective <loss>=0.4393048788403708
# [10/05/2021 07:09:22 INFO 140429084538688] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=binary_classification_cross_entropy_objective, value=0.43040536305261035
# [10/05/2021 07:09:22 INFO 140429084538688] Saving model for epoch: 14
# [10/05/2021 07:09:22 INFO 140429084538688] Saved checkpoint to "/tmp/tmpx8878fjp/mx-mod-0000.params"
# [10/05/2021 07:09:22 INFO 140429084538688] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1633417760.0532742, "EndTime": 1633417762.3806913, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 961320.0, "count": 1, "min": 961320, "max": 961320}, "Total Batches Seen": {"sum": 972.0, "count": 1, "min": 972, "max": 972}, "Max Records Seen Between Resets": {"sum": 63288.0, "count": 1, "min": 63288, "max": 63288}, "Max Batches Seen Between Resets": {"sum": 64.0, "count": 1, "min": 64, "max": 64}, "Reset Count": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Number of Records Since Last Reset": {"sum": 63288.0, "count": 1, "min": 63288, "max": 63288}, "Number of Batches Since Last Reset": {"sum": 64.0, "count": 1, "min": 64, "max": 64}}}
#
# [10/05/2021 07:09:22 INFO 140429084538688] #throughput_metric: host=algo-1, train throughput=27190.974138935944 records/second
# [10/05/2021 07:09:22 WARNING 140429084538688] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [10/05/2021 07:09:22 WARNING 140429084538688] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2021-10-05 07:09:22.385] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 33, "duration": 3, "num_examples": 1, "num_bytes": 84000}
# [2021-10-05 07:09:22.622] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 235, "num_examples": 64, "num_bytes": 5316192}
# [2021-10-05 07:09:22.913] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 38, "duration": 253, "num_examples": 64, "num_bytes": 5316192}
# [10/05/2021 07:09:22 INFO 140429084538688] #train_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.45429002812230895)
# [10/05/2021 07:09:22 INFO 140429084538688] #train_score (algo-1) : ('binary_classification_accuracy', 0.785425357097712)
# [10/05/2021 07:09:22 INFO 140429084538688] #train_score (algo-1) : ('binary_f_1.000', 0.8704074816299265)
# [10/05/2021 07:09:22 INFO 140429084538688] #train_score (algo-1) : ('precision', 0.8041933379181435)
# [10/05/2021 07:09:22 INFO 140429084538688] #train_score (algo-1) : ('recall', 0.9485035668975271)
# [10/05/2021 07:09:22 INFO 140429084538688] #train_score (algo-1) : ('roc_auc_score', 0.8187995341430307)
# [10/05/2021 07:09:22 INFO 140429084538688] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=0.45429002812230895
# [10/05/2021 07:09:22 INFO 140429084538688] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.785425357097712
# [10/05/2021 07:09:22 INFO 140429084538688] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.8704074816299265
# [10/05/2021 07:09:22 INFO 140429084538688] #quality_metric: host=algo-1, train precision <score>=0.8041933379181435
# [10/05/2021 07:09:22 INFO 140429084538688] #quality_metric: host=algo-1, train recall <score>=0.9485035668975271
# [10/05/2021 07:09:22 INFO 140429084538688] #quality_metric: host=algo-1, train roc_auc_score <score>=0.8187995341430307
# [10/05/2021 07:09:22 INFO 140429084538688] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.1, "wd": 0.0001, "l1": 0.0, "lr_scheduler_step": 100, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 0.0001}
# [10/05/2021 07:09:22 INFO 140429084538688] Saved checkpoint to "/tmp/tmpj3ykr7td/mx-mod-0000.params"
# [10/05/2021 07:09:22 INFO 140429084538688] Test data is not provided.
# #metrics {"StartTime": 1633417726.9706097, "EndTime": 1633417762.943842, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 253.10826301574707, "count": 1, "min": 253.10826301574707, "max": 253.10826301574707}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 12.88914680480957, "count": 15, "min": 0.2071857452392578, "max": 1.2993812561035156}, "update.time": {"sum": 35089.658975601196, "count": 15, "min": 2040.4839515686035, "max": 2781.862497329712}, "finalize.time": {"sum": 557.0573806762695, "count": 1, "min": 557.0573806762695, "max": 557.0573806762695}, "setuptime": {"sum": 25.60138702392578, "count": 1, "min": 25.60138702392578, "max": 25.60138702392578}, "totaltime": {"sum": 36201.489210128784, "count": 1, "min": 36201.489210128784, "max": 36201.489210128784}}}
#
# Training seconds: 98
# Billable seconds: 98
# CPU times: user 633 ms, sys: 49.4 ms, total: 683 ms
# Wall time: 4min 12s

# %%
# %%time 
# deploy and create a predictor
linear_predictor = linear.deploy(initial_instance_count=1, instance_type='ml.t2.medium')
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# ---------!CPU times: user 183 ms, sys: 10 ms, total: 193 ms
# Wall time: 4min 32s

# %%
features.values.astype('float32')
# Out:
# array([[0.18072289, 0.46666667, 1.        , ..., 1.        , 0.        ,
#         0.        ],
#        [0.4384762 , 0.3933888 , 1.        , ..., 0.        , 0.        ,
#         1.        ],
#        [0.07228915, 0.33333334, 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.5060241 , 0.5888889 , 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.42168674, 0.82222223, 1.        , ..., 1.        , 0.        ,
#         0.        ],
#        [0.6626506 , 0.6       , 1.        , ..., 0.        , 0.        ,
#         0.        ]], dtype=float32)

# %% [markdown]
# ### Helper function for evaluation
#
#
# The provided function below, takes in a deployed predictor, some test features and labels, and returns a dictionary of metrics; calculating false negatives and positives as well as recall, precision, and accuracy.

# %%
# code to evaluate the endpoint on test data
# returns a variety of model metrics
def evaluate(predictor, test_features, test_labels, verbose=True):
    """
    Evaluate a model on a test set given the prediction endpoint.  
    Return binary classification metrics.
    :param predictor: A prediction endpoint
    :param test_features: Test features
    :param test_labels: Class labels for test data
    :param verbose: If True, prints a table of all performance metrics
    :return: A dictionary of performance metrics.
    """
    
    # We have a lot of test data, so we'll split it into batches of 100
    # split the test data set into batches and evaluate using prediction endpoint    
    prediction_batches = [predictor.predict(batch) for batch in np.array_split(test_features, 100)]
    
    # LinearLearner produces a `predicted_label` for each data point in a batch
    # get the 'predicted_label' for every point in a batch
    test_preds = np.concatenate([np.array([x.label['predicted_label'].float32_tensor.values[0] for x in batch]) 
                                 for batch in prediction_batches])
    
    # calculate true positives, false positives, true negatives, false negatives
    tp = np.logical_and(test_labels, test_preds).sum()
    fp = np.logical_and(1-test_labels, test_preds).sum()
    tn = np.logical_and(1-test_labels, 1-test_preds).sum()
    fn = np.logical_and(test_labels, 1-test_preds).sum()
    
    # calculate binary classification metrics
    recall = tp / (tp + fn)
    precision = tp / (tp + fp)
    accuracy = (tp + tn) / (tp + fp + tn + fn)
    
    # printing a table of metrics
    if verbose:
        print(pd.crosstab(test_labels, test_preds, rownames=['actual (row)'], colnames=['prediction (col)']))
        print("\n{:<11} {:.3f}".format('Recall:', recall))
        print("{:<11} {:.3f}".format('Precision:', precision))
        print("{:<11} {:.3f}".format('Accuracy:', accuracy))
        print()
        
    return {'TP': tp, 'FP': fp, 'FN': fn, 'TN': tn, 
            'Precision': precision, 'Recall': recall, 'Accuracy': accuracy}

# %%
labels.values.flatten()
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %% [markdown]
# ### Test Results
#
# The cell below runs the `evaluate` function.
#
# The code assumes that you have a defined `predictor` and `test_features` and `test_labels` from previously-run cells.

# %%
print('Metrics for simple, LinearLearner.\n')

# get metrics for linear predictor
metrics = evaluate(linear_predictor, 
                   features.values.astype('float32'), 
                   labels.values.flatten(), 
                   verbose=True) # verbose means we'll print out the metrics
# Out:
# Metrics for simple, LinearLearner.
#
# prediction (col)   0.0    1.0
# actual (row)
# 0                 4103  11104
# 1                 2476  45605
#
# Recall:     0.949
# Precision:  0.804
# Accuracy:   0.785

# %%
# Deletes a precictor.endpoint
def delete_endpoint(predictor):
        try:
            boto3.client('sagemaker').delete_endpoint(EndpointName=predictor.endpoint_name)
            print('Deleted {}'.format(predictor.endpoint))
        except:
            print('Already deleted: {}'.format(predictor.endpoint_name))

# %%
# delete the predictor endpoint 
delete_endpoint(linear_predictor)
# Out:
# Already deleted: linear-learner-2021-10-05-07-12-30-250

# %%
# instantiate a LinearLearner
# tune the model for a higher recall
linear_recall = LinearLearner(role=role,
                              instance_count=1, 
                              instance_type='ml.m4.xlarge',
                              predictor_type='binary_classifier',
                              output_path=output_path,
                              sagemaker_session=sagemaker_session,
                              epochs=15,
                              binary_classifier_model_selection_criteria='precision_at_target_recall', # target recall
                              target_recall=0.9) # 90% recall

# %%
# %%time 
# train the estimator on formatted training data
linear_recall.fit(formatted_train_data)
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2021-10-04 12:05:55 Starting - Starting the training job...
# 2021-10-04 12:06:18 Starting - Launching requested ML instancesProfilerReport-1633349154: InProgress
# ......
# 2021-10-04 12:07:19 Starting - Preparing the instances for training.........
# 2021-10-04 12:08:49 Downloading - Downloading input data...
# 2021-10-04 12:09:19 Training - Downloading the training image...
# 2021-10-04 12:09:40 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [10/04/2021 12:09:46 INFO 140633106163520] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [10/04/2021 12:09:46 INFO 140633106163520] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '16', 'predictor_type': 'binary_classifier', 'epochs': '15', 'target_recall': '0.9', 'binary_classifier_model_selection_criteria': 'precision_at_target_recall', 'mini_batch_size': '1000'}
# [10/04/2021 12:09:46 INFO 140633106163520] Final configuration: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': '16', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'precision_at_target_recall', 'f_beta': '1.0', 'target_recall': '0.9', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'binary_classifier'}
# [10/04/2021 12:09:46 WARNING 140633106163520] Loggers have already been setup.
# Process 1 is a worker.
# [10/04/2021 12:09:46 INFO 140633106163520] Using default worker.
# [10/04/2021 12:09:46 INFO 140633106163520] Checkpoint loading and saving are disabled.
# [2021-10-04 12:09:46.683] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 20, "num_examples": 1, "num_bytes": 108000}
# [10/04/2021 12:09:46 INFO 140633106163520] Create Store: local
# [2021-10-04 12:09:46.772] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 88, "num_examples": 11, "num_bytes": 1188000}
# [10/04/2021 12:09:46 INFO 140633106163520] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7fe751b4f210>
# [10/04/2021 12:09:46 INFO 140633106163520] Scaling model computed with parameters:
#  {'stdev_label': None, 'stdev_weight':
# [ 0.19719602  0.22645733  1.4855342   2.4758902  59.42136     1.
#   1.          1.          1.          0.48231107  0.4999712   0.10847703
#   0.3184726   0.495178    0.49517807  1.        ]
# <NDArray 16 @cpu(0)>, 'mean_label': None, 'mean_weight':
# [4.4055510e-01 3.9739019e-01 3.7078183e+00 7.1536365e+00 1.7168729e+02
#  1.0000000e+00 1.0000000e+00 1.0000000e+00 1.0000000e+00 3.6818185e-01
#  5.0536376e-01 1.1909093e-02 1.1454546e-01 5.6927270e-01 4.3072730e-01
#  0.0000000e+00]
# <NDArray 16 @cpu(0)>}
# [10/04/2021 12:09:46 INFO 140633106163520] nvidia-smi: took 0.031 seconds to run.
# [10/04/2021 12:09:46 INFO 140633106163520] nvidia-smi identified 0 GPUs.
# [10/04/2021 12:09:46 INFO 140633106163520] Number of GPUs being used: 0
# #metrics {"StartTime": 1633349386.9182174, "EndTime": 1633349386.9182584, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 12000.0, "count": 1, "min": 12000, "max": 12000}, "Total Batches Seen": {"sum": 12.0, "count": 1, "min": 12, "max": 12}, "Max Records Seen Between Resets": {"sum": 11000.0, "count": 1, "min": 11000, "max": 11000}, "Max Batches Seen Between Resets": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [2021-10-04 12:09:49.272] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 2353, "num_examples": 64, "num_bytes": 6835104}
# #metrics {"StartTime": 1633349389.2727718, "EndTime": 1633349389.2728822, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6542436068095858, "count": 1, "min": 0.6542436068095858, "max": 0.6542436068095858}}}
#
# #metrics {"StartTime": 1633349389.2729905, "EndTime": 1633349389.2730136, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6549853893461681, "count": 1, "min": 0.6549853893461681, "max": 0.6549853893461681}}}
#
# #metrics {"StartTime": 1633349389.2730775, "EndTime": 1633349389.273096, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6603812226795015, "count": 1, "min": 0.6603812226795015, "max": 0.6603812226795015}}}
#
# #metrics {"StartTime": 1633349389.2731543, "EndTime": 1633349389.2731726, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.657853744264633, "count": 1, "min": 0.657853744264633, "max": 0.657853744264633}}}
#
# #metrics {"StartTime": 1633349389.2732291, "EndTime": 1633349389.2732465, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.8295912354484437, "count": 1, "min": 0.8295912354484437, "max": 0.8295912354484437}}}
#
# #metrics {"StartTime": 1633349389.273302, "EndTime": 1633349389.273321, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.8458746158660404, "count": 1, "min": 0.8458746158660404, "max": 0.8458746158660404}}}
#
# #metrics {"StartTime": 1633349389.2733757, "EndTime": 1633349389.2733939, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.831797366187686, "count": 1, "min": 0.831797366187686, "max": 0.831797366187686}}}
#
# #metrics {"StartTime": 1633349389.2734497, "EndTime": 1633349389.2734668, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.8538980795239646, "count": 1, "min": 0.8538980795239646, "max": 0.8538980795239646}}}
#
# #metrics {"StartTime": 1633349389.2735312, "EndTime": 1633349389.2735484, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6502899082728795, "count": 1, "min": 0.6502899082728795, "max": 0.6502899082728795}}}
#
# #metrics {"StartTime": 1633349389.2736127, "EndTime": 1633349389.2736313, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6571238897414434, "count": 1, "min": 0.6571238897414434, "max": 0.6571238897414434}}}
#
# #metrics {"StartTime": 1633349389.273685, "EndTime": 1633349389.2737033, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6483294648670015, "count": 1, "min": 0.6483294648670015, "max": 0.6483294648670015}}}
#
# #metrics {"StartTime": 1633349389.273759, "EndTime": 1633349389.2737772, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6616265733506944, "count": 1, "min": 0.6616265733506944, "max": 0.6616265733506944}}}
#
# #metrics {"StartTime": 1633349389.273832, "EndTime": 1633349389.2738483, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.8386132473415798, "count": 1, "min": 0.8386132473415798, "max": 0.8386132473415798}}}
#
# #metrics {"StartTime": 1633349389.273903, "EndTime": 1633349389.2739205, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.8411857779366629, "count": 1, "min": 0.8411857779366629, "max": 0.8411857779366629}}}
#
# #metrics {"StartTime": 1633349389.2739737, "EndTime": 1633349389.273991, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.8287288048153831, "count": 1, "min": 0.8287288048153831, "max": 0.8287288048153831}}}
#
# #metrics {"StartTime": 1633349389.2740505, "EndTime": 1633349389.274067, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.8251258661179316, "count": 1, "min": 0.8251258661179316, "max": 0.8251258661179316}}}
#
# #metrics {"StartTime": 1633349389.2741187, "EndTime": 1633349389.2741334, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6646310076032366, "count": 1, "min": 0.6646310076032366, "max": 0.6646310076032366}}}
#
# #metrics {"StartTime": 1633349389.274187, "EndTime": 1633349389.2742047, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.668167500813802, "count": 1, "min": 0.668167500813802, "max": 0.668167500813802}}}
#
# #metrics {"StartTime": 1633349389.274266, "EndTime": 1633349389.274284, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6647509213402157, "count": 1, "min": 0.6647509213402157, "max": 0.6647509213402157}}}
#
# #metrics {"StartTime": 1633349389.2743378, "EndTime": 1633349389.2743552, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6675601399739584, "count": 1, "min": 0.6675601399739584, "max": 0.6675601399739584}}}
#
# #metrics {"StartTime": 1633349389.2744148, "EndTime": 1633349389.2744324, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6772252032567584, "count": 1, "min": 0.6772252032567584, "max": 0.6772252032567584}}}
#
# #metrics {"StartTime": 1633349389.2744899, "EndTime": 1633349389.274507, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6749932851640005, "count": 1, "min": 0.6749932851640005, "max": 0.6749932851640005}}}
#
# #metrics {"StartTime": 1633349389.2745488, "EndTime": 1633349389.274564, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6742159864637587, "count": 1, "min": 0.6742159864637587, "max": 0.6742159864637587}}}
#
# #metrics {"StartTime": 1633349389.274613, "EndTime": 1633349389.2746294, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.675691394624256, "count": 1, "min": 0.675691394624256, "max": 0.675691394624256}}}
#
# #metrics {"StartTime": 1633349389.2746785, "EndTime": 1633349389.274692, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6821475093781002, "count": 1, "min": 0.6821475093781002, "max": 0.6821475093781002}}}
#
# #metrics {"StartTime": 1633349389.274738, "EndTime": 1633349389.2747536, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6815904366629464, "count": 1, "min": 0.6815904366629464, "max": 0.6815904366629464}}}
#
# #metrics {"StartTime": 1633349389.274805, "EndTime": 1633349389.2748232, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6801335003565229, "count": 1, "min": 0.6801335003565229, "max": 0.6801335003565229}}}
#
# #metrics {"StartTime": 1633349389.2748756, "EndTime": 1633349389.2748868, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6826988641648065, "count": 1, "min": 0.6826988641648065, "max": 0.6826988641648065}}}
#
# #metrics {"StartTime": 1633349389.2749305, "EndTime": 1633349389.274947, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.709594479031033, "count": 1, "min": 0.709594479031033, "max": 0.709594479031033}}}
#
# #metrics {"StartTime": 1633349389.2750034, "EndTime": 1633349389.2750208, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7142984759618366, "count": 1, "min": 0.7142984759618366, "max": 0.7142984759618366}}}
#
# #metrics {"StartTime": 1633349389.275076, "EndTime": 1633349389.2750921, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7140140816824777, "count": 1, "min": 0.7140140816824777, "max": 0.7140140816824777}}}
#
# #metrics {"StartTime": 1633349389.2751448, "EndTime": 1633349389.2751627, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7135436614505828, "count": 1, "min": 0.7135436614505828, "max": 0.7135436614505828}}}
#
# [10/04/2021 12:09:49 INFO 140633106163520] #quality_metric: host=algo-1, epoch=0, train binary_classification_cross_entropy_objective <loss>=0.6542436068095858
# [10/04/2021 12:09:49 INFO 140633106163520] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_cross_entropy_objective, value=0.6483294648670015
# [10/04/2021 12:09:49 INFO 140633106163520] Epoch 0: Loss improved. Updating best model
# [10/04/2021 12:09:49 INFO 140633106163520] Saving model for epoch: 0
# [10/04/2021 12:09:49 INFO 140633106163520] Saved checkpoint to "/tmp/tmpg7gtja9d/mx-mod-0000.params"
# [10/04/2021 12:09:49 INFO 140633106163520] #progress_metric: host=algo-1, completed 6.666666666666667 % of epochs
# #metrics {"StartTime": 1633349386.9185474, "EndTime": 1633349389.2948122, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 75288.0, "count": 1, "min": 75288, "max": 75288}, "Total Batches Seen": {"sum": 76.0, "count": 1, "min": 76, "max": 76}, "Max Records Seen Between Resets": {"sum": 63288.0, "count": 1, "min": 63288, "max": 63288}, "Max Batches Seen Between Resets": {"sum": 64.0, "count": 1, "min": 64, "max": 64}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 63288.0, "count": 1, "min": 63288, "max": 63288}, "Number of Batches Since Last Reset": {"sum": 64.0, "count": 1, "min": 64, "max": 64}}}
#
# [10/04/2021 12:09:49 INFO 140633106163520] #throughput_metric: host=algo-1, train throughput=26631.94702126018 records/second
# [2021-10-04 12:09:51.972] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 2676, "num_examples": 64, "num_bytes": 6835104}
# #metrics {"StartTime": 1633349391.9721408, "EndTime": 1633349391.9722595, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6245211656358507, "count": 1, "min": 0.6245211656358507, "max": 0.6245211656358507}}}
#
# #metrics {"StartTime": 1633349391.9723556, "EndTime": 1633349391.9724073, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6263577338324653, "count": 1, "min": 0.6263577338324653, "max": 0.6263577338324653}}}
#
# #metrics {"StartTime": 1633349391.9724605, "EndTime": 1633349391.9724727, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6255799512106275, "count": 1, "min": 0.6255799512106275, "max": 0.6255799512106275}}}
#
# #metrics {"StartTime": 1633349391.972513, "EndTime": 1633349391.9725237, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6263994450644841, "count": 1, "min": 0.6263994450644841, "max": 0.6263994450644841}}}
#
# #metrics {"StartTime": 1633349391.9725628, "EndTime": 1633349391.9725733, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.9728806878952753, "count": 1, "min": 0.9728806878952753, "max": 0.9728806878952753}}}
#
# #metrics {"StartTime": 1633349391.9726112, "EndTime": 1633349391.9726217, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.9964205719478547, "count": 1, "min": 0.9964205719478547, "max": 0.9964205719478547}}}
#
# #metrics {"StartTime": 1633349391.972659, "EndTime": 1633349391.9726696, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.9352718544611855, "count": 1, "min": 0.9352718544611855, "max": 0.9352718544611855}}}
#
# #metrics {"StartTime": 1633349391.9727075, "EndTime": 1633349391.9727185, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.9959038696289062, "count": 1, "min": 0.9959038696289062, "max": 0.9959038696289062}}}
#
# #metrics {"StartTime": 1633349391.972784, "EndTime": 1633349391.9727976, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6245398617699033, "count": 1, "min": 0.6245398617699033, "max": 0.6245398617699033}}}
#
# #metrics {"StartTime": 1633349391.9728467, "EndTime": 1633349391.9728584, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6261808413550968, "count": 1, "min": 0.6261808413550968, "max": 0.6261808413550968}}}
#
# #metrics {"StartTime": 1633349391.9728994, "EndTime": 1633349391.9729376, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6240448143368675, "count": 1, "min": 0.6240448143368675, "max": 0.6240448143368675}}}
#
# #metrics {"StartTime": 1633349391.9729903, "EndTime": 1633349391.9730024, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.625352784171937, "count": 1, "min": 0.625352784171937, "max": 0.625352784171937}}}
#
# #metrics {"StartTime": 1633349391.9730482, "EndTime": 1633349391.9730656, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.9081172543480283, "count": 1, "min": 0.9081172543480283, "max": 0.9081172543480283}}}
#
# #metrics {"StartTime": 1633349391.973146, "EndTime": 1633349391.9731588, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.8807780635773189, "count": 1, "min": 0.8807780635773189, "max": 0.8807780635773189}}}
#
# #metrics {"StartTime": 1633349391.9731991, "EndTime": 1633349391.9732099, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.9445815080915179, "count": 1, "min": 0.9445815080915179, "max": 0.9445815080915179}}}
#
# #metrics {"StartTime": 1633349391.9732783, "EndTime": 1633349391.973292, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.9002517535497272, "count": 1, "min": 0.9002517535497272, "max": 0.9002517535497272}}}
#
# #metrics {"StartTime": 1633349391.9733407, "EndTime": 1633349391.9733524, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.652355467781188, "count": 1, "min": 0.652355467781188, "max": 0.652355467781188}}}
#
# #metrics {"StartTime": 1633349391.9733937, "EndTime": 1633349391.9734044, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6519396226671007, "count": 1, "min": 0.6519396226671007, "max": 0.6519396226671007}}}
#
# #metrics {"StartTime": 1633349391.973478, "EndTime": 1633349391.973491, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6521797601609003, "count": 1, "min": 0.6521797601609003, "max": 0.6521797601609003}}}
#
# #metrics {"StartTime": 1633349391.9735372, "EndTime": 1633349391.9735487, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6524807952396453, "count": 1, "min": 0.6524807952396453, "max": 0.6524807952396453}}}
#
# #metrics {"StartTime": 1633349391.973617, "EndTime": 1633349391.9736311, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6922637115962922, "count": 1, "min": 0.6922637115962922, "max": 0.6922637115962922}}}
#
# #metrics {"StartTime": 1633349391.9736626, "EndTime": 1633349391.9736705, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.690853273421999, "count": 1, "min": 0.690853273421999, "max": 0.690853273421999}}}
#
# #metrics {"StartTime": 1633349391.973696, "EndTime": 1633349391.9737031, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.691458233061291, "count": 1, "min": 0.691458233061291, "max": 0.691458233061291}}}
#
# #metrics {"StartTime": 1633349391.9737277, "EndTime": 1633349391.9737349, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6915719662620907, "count": 1, "min": 0.6915719662620907, "max": 0.6915719662620907}}}
#
# #metrics {"StartTime": 1633349391.973813, "EndTime": 1633349391.973825, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6819029725089906, "count": 1, "min": 0.6819029725089906, "max": 0.6819029725089906}}}
#
# #metrics {"StartTime": 1633349391.9738638, "EndTime": 1633349391.9738767, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6833406933981275, "count": 1, "min": 0.6833406933981275, "max": 0.6833406933981275}}}
#
# #metrics {"StartTime": 1633349391.9739206, "EndTime": 1633349391.973935, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6819811265733507, "count": 1, "min": 0.6819811265733507, "max": 0.6819811265733507}}}
#
# #metrics {"StartTime": 1633349391.9740076, "EndTime": 1633349391.9740252, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6825284976050967, "count": 1, "min": 0.6825284976050967, "max": 0.6825284976050967}}}
#
# #metrics {"StartTime": 1633349391.9740856, "EndTime": 1633349391.9741018, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6965001918247767, "count": 1, "min": 0.6965001918247767, "max": 0.6965001918247767}}}
#
# #metrics {"StartTime": 1633349391.974221, "EndTime": 1633349391.9742403, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7012339429098462, "count": 1, "min": 0.7012339429098462, "max": 0.7012339429098462}}}
#
# #metrics {"StartTime": 1633349391.9743013, "EndTime": 1633349391.9743452, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6972740367102245, "count": 1, "min": 0.6972740367102245, "max": 0.6972740367102245}}}
#
# #metrics {"StartTime": 1633349391.9744272, "EndTime": 1633349391.9744463, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7012734810965402, "count": 1, "min": 0.7012734810965402, "max": 0.7012734810965402}}}
#
# [10/04/2021 12:09:51 INFO 140633106163520] #quality_metric: host=algo-1, epoch=1, train binary_classification_cross_entropy_objective <loss>=0.6245211656358507
# [10/04/2021 12:09:51 INFO 140633106163520] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_cross_entropy_objective, value=0.6240448143368675
# [10/04/2021 12:09:51 INFO 140633106163520] Epoch 1: Loss improved. Updating best model
# [10/04/2021 12:09:51 INFO 140633106163520] Saving model for epoch: 1
# [10/04/2021 12:09:51 INFO 140633106163520] Saved checkpoint to "/tmp/tmptiis8iv6/mx-mod-0000.params"
# [10/04/2021 12:09:51 INFO 140633106163520] #progress_metric: host=algo-1, completed 13.333333333333334 % of epochs
# #metrics {"StartTime": 1633349389.2954621, "EndTime": 1633349391.986431, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 138576.0, "count": 1, "min": 138576, "max": 138576}, "Total Batches Seen": {"sum": 140.0, "count": 1, "min": 140, "max": 140}, "Max Records Seen Between Resets": {"sum": 63288.0, "count": 1, "min": 63288, "max": 63288}, "Max Batches Seen Between Resets": {"sum": 64.0, "count": 1, "min": 64, "max": 64}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 63288.0, "count": 1, "min": 63288, "max": 63288}, "Number of Batches Since Last Reset": {"sum": 64.0, "count": 1, "min": 64, "max": 64}}}
#
# [10/04/2021 12:09:51 INFO 140633106163520] #throughput_metric: host=algo-1, train throughput=23517.77802474456 records/second
# [2021-10-04 12:09:54.360] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 7, "duration": 2372, "num_examples": 64, "num_bytes": 6835104}
# #metrics {"StartTime": 1633349394.3600886, "EndTime": 1633349394.3601556, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6171905033172123, "count": 1, "min": 0.6171905033172123, "max": 0.6171905033172123}}}
#
# #metrics {"StartTime": 1633349394.360251, "EndTime": 1633349394.360267, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6173030269562252, "count": 1, "min": 0.6173030269562252, "max": 0.6173030269562252}}}
#
# #metrics {"StartTime": 1633349394.3603024, "EndTime": 1633349394.3603113, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6168132953946552, "count": 1, "min": 0.6168132953946552, "max": 0.6168132953946552}}}
#
# #metrics {"StartTime": 1633349394.360367, "EndTime": 1633349394.3603876, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6182623077876984, "count": 1, "min": 0.6182623077876984, "max": 0.6182623077876984}}}
#
# #metrics {"StartTime": 1633349394.360436, "EndTime": 1633349394.3604522, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.8357942393469432, "count": 1, "min": 0.8357942393469432, "max": 0.8357942393469432}}}
#
# #metrics {"StartTime": 1633349394.3605168, "EndTime": 1633349394.360536, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.8997673988947793, "count": 1, "min": 0.8997673988947793, "max": 0.8997673988947793}}}
#
# #metrics {"StartTime": 1633349394.3605917, "EndTime": 1633349394.3606088, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.8764206349206349, "count": 1, "min": 0.8764206349206349, "max": 0.8764206349206349}}}
#
# #metrics {"StartTime": 1633349394.3606663, "EndTime": 1633349394.360683, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.8791000114319817, "count": 1, "min": 0.8791000114319817, "max": 0.8791000114319817}}}
#
# #metrics {"StartTime": 1633349394.3607392, "EndTime": 1633349394.3607566, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6175737885974703, "count": 1, "min": 0.6175737885974703, "max": 0.6175737885974703}}}
#
# #metrics {"StartTime": 1633349394.360815, "EndTime": 1633349394.360832, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6176595914326017, "count": 1, "min": 0.6176595914326017, "max": 0.6176595914326017}}}
#
# #metrics {"StartTime": 1633349394.3608878, "EndTime": 1633349394.360906, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6169710267082094, "count": 1, "min": 0.6169710267082094, "max": 0.6169710267082094}}}
#
# #metrics {"StartTime": 1633349394.36096, "EndTime": 1633349394.3609772, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6176937352740576, "count": 1, "min": 0.6176937352740576, "max": 0.6176937352740576}}}
#
# #metrics {"StartTime": 1633349394.3610318, "EndTime": 1633349394.3610497, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7401555543929812, "count": 1, "min": 0.7401555543929812, "max": 0.7401555543929812}}}
#
# #metrics {"StartTime": 1633349394.3611164, "EndTime": 1633349394.3611357, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7966570730057974, "count": 1, "min": 0.7966570730057974, "max": 0.7966570730057974}}}
#
# #metrics {"StartTime": 1633349394.361194, "EndTime": 1633349394.361212, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7245667816646515, "count": 1, "min": 0.7245667816646515, "max": 0.7245667816646515}}}
#
# #metrics {"StartTime": 1633349394.3612669, "EndTime": 1633349394.3612838, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7724691922626798, "count": 1, "min": 0.7724691922626798, "max": 0.7724691922626798}}}
#
# #metrics {"StartTime": 1633349394.3613412, "EndTime": 1633349394.361359, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6507763885013641, "count": 1, "min": 0.6507763885013641, "max": 0.6507763885013641}}}
#
# #metrics {"StartTime": 1633349394.3614144, "EndTime": 1633349394.3614326, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6512310606941344, "count": 1, "min": 0.6512310606941344, "max": 0.6512310606941344}}}
#
# #metrics {"StartTime": 1633349394.3614914, "EndTime": 1633349394.3615088, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.650660176595052, "count": 1, "min": 0.650660176595052, "max": 0.650660176595052}}}
#
# #metrics {"StartTime": 1633349394.3615663, "EndTime": 1633349394.3615835, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.651176031203497, "count": 1, "min": 0.651176031203497, "max": 0.651176031203497}}}
#
# #metrics {"StartTime": 1633349394.3616397, "EndTime": 1633349394.3616579, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6841006319560702, "count": 1, "min": 0.6841006319560702, "max": 0.6841006319560702}}}
#
# #metrics {"StartTime": 1633349394.3617244, "EndTime": 1633349394.3617415, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.683747811453683, "count": 1, "min": 0.683747811453683, "max": 0.683747811453683}}}
#
# #metrics {"StartTime": 1633349394.3617973, "EndTime": 1633349394.3618155, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6839217684306795, "count": 1, "min": 0.6839217684306795, "max": 0.6839217684306795}}}
#
# #metrics {"StartTime": 1633349394.361872, "EndTime": 1633349394.3618891, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.683635019938151, "count": 1, "min": 0.683635019938151, "max": 0.683635019938151}}}
#
# #metrics {"StartTime": 1633349394.3619475, "EndTime": 1633349394.3619642, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6811708771236359, "count": 1, "min": 0.6811708771236359, "max": 0.6811708771236359}}}
#
# #metrics {"StartTime": 1633349394.362, "EndTime": 1633349394.3620088, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6821929970393105, "count": 1, "min": 0.6821929970393105, "max": 0.6821929970393105}}}
#
# #metrics {"StartTime": 1633349394.3620398, "EndTime": 1633349394.362054, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6811438104538691, "count": 1, "min": 0.6811438104538691, "max": 0.6811438104538691}}}
#
# #metrics {"StartTime": 1633349394.362105, "EndTime": 1633349394.3621209, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6817959662543402, "count": 1, "min": 0.6817959662543402, "max": 0.6817959662543402}}}
#
# #metrics {"StartTime": 1633349394.3621762, "EndTime": 1633349394.362193, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6955433669317337, "count": 1, "min": 0.6955433669317337, "max": 0.6955433669317337}}}
#
# #metrics {"StartTime": 1633349394.3622513, "EndTime": 1633349394.3622687, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6995460791209387, "count": 1, "min": 0.6995460791209387, "max": 0.6995460791209387}}}
#
# #metrics {"StartTime": 1633349394.3623376, "EndTime": 1633349394.3623552, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.695015371171255, "count": 1, "min": 0.695015371171255, "max": 0.695015371171255}}}
#
# #metrics {"StartTime": 1633349394.3624141, "EndTime": 1633349394.3624308, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6994305623372395, "count": 1, "min": 0.6994305623372395, "max": 0.6994305623372395}}}
#
# [10/04/2021 12:09:54 INFO 140633106163520] #quality_metric: host=algo-1, epoch=2, train binary_classification_cross_entropy_objective <loss>=0.6171905033172123
# [10/04/2021 12:09:54 INFO 140633106163520] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_cross_entropy_objective, value=0.6168132953946552
# [10/04/2021 12:09:54 INFO 140633106163520] Epoch 2: Loss improved. Updating best model
# [10/04/2021 12:09:54 INFO 140633106163520] Saving model for epoch: 2
# [10/04/2021 12:09:54 INFO 140633106163520] Saved checkpoint to "/tmp/tmpk_ddt_rn/mx-mod-0000.params"
# [10/04/2021 12:09:54 INFO 140633106163520] #progress_metric: host=algo-1, completed 20.0 % of epochs
# #metrics {"StartTime": 1633349391.9869978, "EndTime": 1633349394.372706, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 201864.0, "count": 1, "min": 201864, "max": 201864}, "Total Batches Seen": {"sum": 204.0, "count": 1, "min": 204, "max": 204}, "Max Records Seen Between Resets": {"sum": 63288.0, "count": 1, "min": 63288, "max": 63288}, "Max Batches Seen Between Resets": {"sum": 64.0, "count": 1, "min": 64, "max": 64}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 63288.0, "count": 1, "min": 63288, "max": 63288}, "Number of Batches Since Last Reset": {"sum": 64.0, "count": 1, "min": 64, "max": 64}}}
#
# [10/04/2021 12:09:54 INFO 140633106163520] #throughput_metric: host=algo-1, train throughput=26526.353318418434 records/second
# [2021-10-04 12:09:56.875] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 9, "duration": 2501, "num_examples": 64, "num_bytes": 6835104}
# #metrics {"StartTime": 1633349396.8753428, "EndTime": 1633349396.875408, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6156181388733879, "count": 1, "min": 0.6156181388733879, "max": 0.6156181388733879}}}
#
# #metrics {"StartTime": 1633349396.875481, "EndTime": 1633349396.875495, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.61599315437438, "count": 1, "min": 0.61599315437438, "max": 0.61599315437438}}}
#
# #metrics {"StartTime": 1633349396.8755276, "EndTime": 1633349396.8755443, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6152312651134673, "count": 1, "min": 0.6152312651134673, "max": 0.6152312651134673}}}
#
# #metrics {"StartTime": 1633349396.875573, "EndTime": 1633349396.8755867, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6167495688786583, "count": 1, "min": 0.6167495688786583, "max": 0.6167495688786583}}}
#
# #metrics {"StartTime": 1633349396.8756354, "EndTime": 1633349396.8756518, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7597027277870784, "count": 1, "min": 0.7597027277870784, "max": 0.7597027277870784}}}
#
# #metrics {"StartTime": 1633349396.8757005, "EndTime": 1633349396.8757155, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.8305730227515811, "count": 1, "min": 0.8305730227515811, "max": 0.8305730227515811}}}
#
# ...
#
# #metrics {"StartTime": 1633349412.2794545, "EndTime": 1633349412.279467, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6117274978879899, "count": 1, "min": 0.6117274978879899, "max": 0.6117274978879899}}}
#
# #metrics {"StartTime": 1633349412.2795198, "EndTime": 1633349412.2795374, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6139103432307168, "count": 1, "min": 0.6139103432307168, "max": 0.6139103432307168}}}
#
# #metrics {"StartTime": 1633349412.2796059, "EndTime": 1633349412.2796257, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.8531180560399616, "count": 1, "min": 0.8531180560399616, "max": 0.8531180560399616}}}
#
# #metrics {"StartTime": 1633349412.2796874, "EndTime": 1633349412.2797053, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.998745370531839, "count": 1, "min": 0.998745370531839, "max": 0.998745370531839}}}
#
# #metrics {"StartTime": 1633349412.279776, "EndTime": 1633349412.2797947, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.8931780739436074, "count": 1, "min": 0.8931780739436074, "max": 0.8931780739436074}}}
#
# #metrics {"StartTime": 1633349412.2798615, "EndTime": 1633349412.2798796, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 1.0986615426199777, "count": 1, "min": 1.0986615426199777, "max": 1.0986615426199777}}}
#
# #metrics {"StartTime": 1633349412.2799485, "EndTime": 1633349412.2799668, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6121481546068949, "count": 1, "min": 0.6121481546068949, "max": 0.6121481546068949}}}
#
# #metrics {"StartTime": 1633349412.280022, "EndTime": 1633349412.2800379, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6137378709581163, "count": 1, "min": 0.6137378709581163, "max": 0.6137378709581163}}}
#
# #metrics {"StartTime": 1633349412.280111, "EndTime": 1633349412.2801273, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.611863537500775, "count": 1, "min": 0.611863537500775, "max": 0.611863537500775}}}
#
# #metrics {"StartTime": 1633349412.2801895, "EndTime": 1633349412.2802079, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6138799060639881, "count": 1, "min": 0.6138799060639881, "max": 0.6138799060639881}}}
#
# #metrics {"StartTime": 1633349412.280267, "EndTime": 1633349412.2802854, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6823852146693639, "count": 1, "min": 0.6823852146693639, "max": 0.6823852146693639}}}
#
# #metrics {"StartTime": 1633349412.2803826, "EndTime": 1633349412.2804036, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.8814378032381572, "count": 1, "min": 0.8814378032381572, "max": 0.8814378032381572}}}
#
# #metrics {"StartTime": 1633349412.280466, "EndTime": 1633349412.280485, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6665487651522197, "count": 1, "min": 0.6665487651522197, "max": 0.6665487651522197}}}
#
# #metrics {"StartTime": 1633349412.2805414, "EndTime": 1633349412.2805583, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.8515098586309524, "count": 1, "min": 0.8515098586309524, "max": 0.8515098586309524}}}
#
# #metrics {"StartTime": 1633349412.2806218, "EndTime": 1633349412.2806404, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6492012706938244, "count": 1, "min": 0.6492012706938244, "max": 0.6492012706938244}}}
#
# #metrics {"StartTime": 1633349412.280706, "EndTime": 1633349412.280724, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6514027894035218, "count": 1, "min": 0.6514027894035218, "max": 0.6514027894035218}}}
#
# #metrics {"StartTime": 1633349412.2807922, "EndTime": 1633349412.2808104, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6491980774894593, "count": 1, "min": 0.6491980774894593, "max": 0.6491980774894593}}}
#
# #metrics {"StartTime": 1633349412.2808728, "EndTime": 1633349412.2808895, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6513846086774554, "count": 1, "min": 0.6513846086774554, "max": 0.6513846086774554}}}
#
# #metrics {"StartTime": 1633349412.2809503, "EndTime": 1633349412.2809672, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6921166464184958, "count": 1, "min": 0.6921166464184958, "max": 0.6921166464184958}}}
#
# #metrics {"StartTime": 1633349412.281019, "EndTime": 1633349412.2810342, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6826018395802331, "count": 1, "min": 0.6826018395802331, "max": 0.6826018395802331}}}
#
# #metrics {"StartTime": 1633349412.281087, "EndTime": 1633349412.2811048, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6921771884494358, "count": 1, "min": 0.6921771884494358, "max": 0.6921771884494358}}}
#
# #metrics {"StartTime": 1633349412.2811565, "EndTime": 1633349412.281174, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6825949082147508, "count": 1, "min": 0.6825949082147508, "max": 0.6825949082147508}}}
#
# #metrics {"StartTime": 1633349412.281232, "EndTime": 1633349412.2812486, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6791086687360491, "count": 1, "min": 0.6791086687360491, "max": 0.6791086687360491}}}
#
# #metrics {"StartTime": 1633349412.2813046, "EndTime": 1633349412.281322, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6815361609080481, "count": 1, "min": 0.6815361609080481, "max": 0.6815361609080481}}}
#
# #metrics {"StartTime": 1633349412.2813792, "EndTime": 1633349412.2813966, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6790873083689856, "count": 1, "min": 0.6790873083689856, "max": 0.6790873083689856}}}
#
# #metrics {"StartTime": 1633349412.2814503, "EndTime": 1633349412.2814677, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.68157130843874, "count": 1, "min": 0.68157130843874, "max": 0.68157130843874}}}
#
# #metrics {"StartTime": 1633349412.281519, "EndTime": 1633349412.2815347, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6894351646786644, "count": 1, "min": 0.6894351646786644, "max": 0.6894351646786644}}}
#
# #metrics {"StartTime": 1633349412.281586, "EndTime": 1633349412.2816038, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6982583569723463, "count": 1, "min": 0.6982583569723463, "max": 0.6982583569723463}}}
#
# #metrics {"StartTime": 1633349412.2816513, "EndTime": 1633349412.2816615, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6896834392244854, "count": 1, "min": 0.6896834392244854, "max": 0.6896834392244854}}}
#
# #metrics {"StartTime": 1633349412.281696, "EndTime": 1633349412.2817113, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6979954824296255, "count": 1, "min": 0.6979954824296255, "max": 0.6979954824296255}}}
#
# [10/04/2021 12:10:12 INFO 140633106163520] #quality_metric: host=algo-1, epoch=9, train binary_classification_cross_entropy_objective <loss>=0.6119371110219805
# [10/04/2021 12:10:12 INFO 140633106163520] #early_stopping_criteria_metric: host=algo-1, epoch=9, criteria=binary_classification_cross_entropy_objective, value=0.6117274978879899
# [10/04/2021 12:10:12 INFO 140633106163520] Saving model for epoch: 9
# [10/04/2021 12:10:12 INFO 140633106163520] Saved checkpoint to "/tmp/tmpse448kq8/mx-mod-0000.params"
# [10/04/2021 12:10:12 INFO 140633106163520] Early stop condition met. Stopping training.
# [10/04/2021 12:10:12 INFO 140633106163520] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"StartTime": 1633349409.8523064, "EndTime": 1633349412.2918174, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 644880.0, "count": 1, "min": 644880, "max": 644880}, "Total Batches Seen": {"sum": 652.0, "count": 1, "min": 652, "max": 652}, "Max Records Seen Between Resets": {"sum": 63288.0, "count": 1, "min": 63288, "max": 63288}, "Max Batches Seen Between Resets": {"sum": 64.0, "count": 1, "min": 64, "max": 64}, "Reset Count": {"sum": 12.0, "count": 1, "min": 12, "max": 12}, "Number of Records Since Last Reset": {"sum": 63288.0, "count": 1, "min": 63288, "max": 63288}, "Number of Batches Since Last Reset": {"sum": 64.0, "count": 1, "min": 64, "max": 64}}}
#
# [10/04/2021 12:10:12 INFO 140633106163520] #throughput_metric: host=algo-1, train throughput=25941.27582563065 records/second
# [10/04/2021 12:10:12 WARNING 140633106163520] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [10/04/2021 12:10:12 WARNING 140633106163520] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2021-10-04 12:10:12.296] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 23, "duration": 3, "num_examples": 1, "num_bytes": 108000}
# [2021-10-04 12:10:12.547] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 26, "duration": 248, "num_examples": 64, "num_bytes": 6835104}
# [2021-10-04 12:10:12.874] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 28, "duration": 262, "num_examples": 64, "num_bytes": 6835104}
# [10/04/2021 12:10:12 INFO 140633106163520] #train_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.6091972382899528)
# [10/04/2021 12:10:12 INFO 140633106163520] #train_score (algo-1) : ('binary_classification_accuracy', 0.6836051068132979)
# [10/04/2021 12:10:12 INFO 140633106163520] #train_score (algo-1) : ('binary_f_1.000', 0.7704038342467953)
# [10/04/2021 12:10:12 INFO 140633106163520] #train_score (algo-1) : ('precision', 0.6710946863763484)
# [10/04/2021 12:10:12 INFO 140633106163520] #train_score (algo-1) : ('recall', 0.9042095063788556)
# [10/04/2021 12:10:12 INFO 140633106163520] #train_score (algo-1) : ('roc_auc_score', 0.7013340813233657)
# [10/04/2021 12:10:12 INFO 140633106163520] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=0.6091972382899528
# [10/04/2021 12:10:12 INFO 140633106163520] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.6836051068132979
# [10/04/2021 12:10:12 INFO 140633106163520] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.7704038342467953
# [10/04/2021 12:10:12 INFO 140633106163520] #quality_metric: host=algo-1, train precision <score>=0.6710946863763484
# [10/04/2021 12:10:12 INFO 140633106163520] #quality_metric: host=algo-1, train recall <score>=0.9042095063788556
# [10/04/2021 12:10:12 INFO 140633106163520] #quality_metric: host=algo-1, train roc_auc_score <score>=0.7013340813233657
# [10/04/2021 12:10:12 INFO 140633106163520] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.005, "wd": 0.0001, "l1": 0.0, "lr_scheduler_step": 10, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 0.0001}
# [10/04/2021 12:10:12 INFO 140633106163520] Saved checkpoint to "/tmp/tmp15yq5rik/mx-mod-0000.params"
# [10/04/2021 12:10:12 INFO 140633106163520] Test data is not provided.
# #metrics {"StartTime": 1633349386.66245, "EndTime": 1633349412.905907, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 252.6094913482666, "count": 1, "min": 252.6094913482666, "max": 252.6094913482666}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 8.383512496948242, "count": 10, "min": 0.22292137145996094, "max": 1.451253890991211}, "update.time": {"sum": 25317.837238311768, "count": 10, "min": 2156.1925411224365, "max": 2974.4439125061035}, "finalize.time": {"sum": 607.8791618347168, "count": 1, "min": 607.8791618347168, "max": 607.8791618347168}, "setuptime": {"sum": 26.488304138183594, "count": 1, "min": 26.488304138183594, "max": 26.488304138183594}, "totaltime": {"sum": 26487.62583732605, "count": 1, "min": 26487.62583732605, "max": 26487.62583732605}}}
#
# Training seconds: 96
# Billable seconds: 96
# CPU times: user 629 ms, sys: 50.9 ms, total: 680 ms
# Wall time: 4min 42s

# %%
# %%time 
# deploy and create a predictor
recall_predictor = linear_recall.deploy(initial_instance_count=1, instance_type='ml.t2.medium')
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# -----------!CPU times: user 298 ms, sys: 5.04 ms, total: 303 ms
# Wall time: 5min 33s

# %%
print('Metrics for tuned (recall), LinearLearner.\n')

# get metrics for tuned predictor
metrics = evaluate(recall_predictor, 
                   features.values.astype('float32'), 
                   labels.values.flatten(), 
                   verbose=True)
# Out:
# Metrics for tuned (recall), LinearLearner.
#
# prediction (col)   0.0    1.0
# actual (row)
# 0                 9669  16465
# 1                 3559  33595
#
# Recall:     0.904
# Precision:  0.671
# Accuracy:   0.684

# %% [markdown]
# ## Delete the endpoint
#
# As always, when you're done evaluating a model, you should delete the endpoint. Below, I'm using the `delete_endpoint` helper function I defined earlier.

# %%
# delete the predictor endpoint 
delete_endpoint(recall_predictor)
# Out:
# Already deleted: linear-learner-2021-09-21-11-07-47-455

# %%
sagemaker_session.delete_endpoint(endpoint_name='linear-learner-2021-09-21-11-07-47-455')

# %%
# instantiate a LinearLearner

# include params for tuning for higher recall
# *and* account for class imbalance in training data
linear_balanced = LinearLearner(role=role,
                                instance_count=1, 
                                instance_type='ml.c4.xlarge',
                                predictor_type='binary_classifier',
                                output_path=output_path,
                                sagemaker_session=sagemaker_session,
                                epochs=15,
                                binary_classifier_model_selection_criteria='precision_at_target_recall', # target recall
                                target_recall=0.9,
                                positive_example_weight_mult='balanced')

# %% [markdown]
# ### EXERCISE: Train the balanced estimator
#
# Fit the new, balanced estimator on the formatted training data.

# %%
# %%time 
# train the estimator on formatted training data
linear_balanced.fit(formatted_train_data)
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2021-09-21 11:25:46 Starting - Starting the training job...
# 2021-09-21 11:25:48 Starting - Launching requested ML instancesProfilerReport-1632223546: InProgress
# ......
# 2021-09-21 11:27:16 Starting - Preparing the instances for training.........
# 2021-09-21 11:28:39 Downloading - Downloading input data...
# 2021-09-21 11:29:17 Training - Downloading the training image.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [09/21/2021 11:29:23 INFO 139736075499328] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [09/21/2021 11:29:23 INFO 139736075499328] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'positive_example_weight_mult': 'balanced', 'feature_dim': '25', 'predictor_type': 'binary_classifier', 'epochs': '15', 'target_recall': '0.9', 'binary_classifier_model_selection_criteria': 'precision_at_target_recall', 'mini_batch_size': '1000'}
# [09/21/2021 11:29:23 INFO 139736075499328] Final configuration: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': '25', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'precision_at_target_recall', 'f_beta': '1.0', 'target_recall': '0.9', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': 'balanced', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'binary_classifier'}
# [09/21/2021 11:29:23 WARNING 139736075499328] Loggers have already been setup.
# Process 1 is a worker.
# [09/21/2021 11:29:23 INFO 139736075499328] Using default worker.
# [09/21/2021 11:29:23 INFO 139736075499328] Checkpoint loading and saving are disabled.
# [2021-09-21 11:29:23.270] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 20, "num_examples": 1, "num_bytes": 144000}
# [09/21/2021 11:29:23 INFO 139736075499328] Create Store: local
# [2021-09-21 11:29:23.357] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 85, "num_examples": 11, "num_bytes": 1584000}
# [09/21/2021 11:29:23 INFO 139736075499328] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f1676a415d0>
# [09/21/2021 11:29:23 INFO 139736075499328] Scaling model computed with parameters:
#  {'stdev_label': None, 'stdev_weight':
# [ 0.1970889   0.22401631  0.22606684  0.49998924  0.4798406   0.10682771
#   0.33154175  0.34848985  0.35831454  0.34951574  0.34998012  0.34065235
#   0.34708133  0.35491967  0.99949944  1.3827184   4.6090612  33.185238
#   1.          1.          1.          1.          0.46090618  1.
#   1.        ]
# <NDArray 25 @cpu(0)>, 'mean_label': None, 'mean_weight':
# [ 4.3743291e-01  3.9324462e-01  2.8580213e-01  5.0327277e-01
#   3.5945460e-01  1.1545457e-02  1.2572727e-01  1.4145455e-01
#   1.5127273e-01  1.4245456e-01  1.4290908e-01  1.3400000e-01
#   1.4009093e-01  1.4781821e-01 -3.1636365e-02  2.9185457e+00
#   1.3061819e+01  1.9004509e+02  0.0000000e+00  1.0000000e+00
#   0.0000000e+00  1.0000000e+00  6.9381821e-01  0.0000000e+00
#   1.0000000e+00]
# <NDArray 25 @cpu(0)>}
# [09/21/2021 11:29:23 INFO 139736075499328] nvidia-smi: took 0.031 seconds to run.
# [09/21/2021 11:29:23 INFO 139736075499328] nvidia-smi identified 0 GPUs.
# [09/21/2021 11:29:23 INFO 139736075499328] Number of GPUs being used: 0
# #metrics {"StartTime": 1632223763.5496929, "EndTime": 1632223763.549729, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 12000.0, "count": 1, "min": 12000, "max": 12000}, "Total Batches Seen": {"sum": 12.0, "count": 1, "min": 12, "max": 12}, "Max Records Seen Between Resets": {"sum": 11000.0, "count": 1, "min": 11000, "max": 11000}, "Max Batches Seen Between Resets": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [2021-09-21 11:29:26.156] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 2605, "num_examples": 77, "num_bytes": 10983888}
# #metrics {"StartTime": 1632223766.1562886, "EndTime": 1632223766.15638, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6242944745515522, "count": 1, "min": 0.6242944745515522, "max": 0.6242944745515522}}}
#
# #metrics {"StartTime": 1632223766.1564846, "EndTime": 1632223766.1565058, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6293442270379317, "count": 1, "min": 0.6293442270379317, "max": 0.6293442270379317}}}
#
# #metrics {"StartTime": 1632223766.1565566, "EndTime": 1632223766.1565714, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.620601487812243, "count": 1, "min": 0.620601487812243, "max": 0.620601487812243}}}
#
# #metrics {"StartTime": 1632223766.156616, "EndTime": 1632223766.156631, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6300730149118524, "count": 1, "min": 0.6300730149118524, "max": 0.6300730149118524}}}
#
# #metrics {"StartTime": 1632223766.1566787, "EndTime": 1632223766.1566932, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.613308205052426, "count": 1, "min": 0.613308205052426, "max": 0.613308205052426}}}
#
# #metrics {"StartTime": 1632223766.1567523, "EndTime": 1632223766.1567693, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6233708893625359, "count": 1, "min": 0.6233708893625359, "max": 0.6233708893625359}}}
#
# #metrics {"StartTime": 1632223766.156822, "EndTime": 1632223766.156839, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6511870711477179, "count": 1, "min": 0.6511870711477179, "max": 0.6511870711477179}}}
#
# #metrics {"StartTime": 1632223766.1568983, "EndTime": 1632223766.156915, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6165536490992496, "count": 1, "min": 0.6165536490992496, "max": 0.6165536490992496}}}
#
# #metrics {"StartTime": 1632223766.156967, "EndTime": 1632223766.1569824, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6212738800048828, "count": 1, "min": 0.6212738800048828, "max": 0.6212738800048828}}}
#
# #metrics {"StartTime": 1632223766.157032, "EndTime": 1632223766.1570468, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6316399038214433, "count": 1, "min": 0.6316399038214433, "max": 0.6316399038214433}}}
#
# #metrics {"StartTime": 1632223766.157098, "EndTime": 1632223766.1571362, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6242067758660568, "count": 1, "min": 0.6242067758660568, "max": 0.6242067758660568}}}
#
# #metrics {"StartTime": 1632223766.1571999, "EndTime": 1632223766.1572158, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6284091467606394, "count": 1, "min": 0.6284091467606394, "max": 0.6284091467606394}}}
#
# #metrics {"StartTime": 1632223766.1572754, "EndTime": 1632223766.1572926, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6695450600071957, "count": 1, "min": 0.6695450600071957, "max": 0.6695450600071957}}}
#
# #metrics {"StartTime": 1632223766.157343, "EndTime": 1632223766.1573584, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6130007099352385, "count": 1, "min": 0.6130007099352385, "max": 0.6130007099352385}}}
#
# #metrics {"StartTime": 1632223766.157418, "EndTime": 1632223766.1574342, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6115877954583419, "count": 1, "min": 0.6115877954583419, "max": 0.6115877954583419}}}
#
# #metrics {"StartTime": 1632223766.1574848, "EndTime": 1632223766.1575005, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6089744435360557, "count": 1, "min": 0.6089744435360557, "max": 0.6089744435360557}}}
#
# #metrics {"StartTime": 1632223766.1575525, "EndTime": 1632223766.1575685, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6499158742804276, "count": 1, "min": 0.6499158742804276, "max": 0.6499158742804276}}}
#
# #metrics {"StartTime": 1632223766.1576102, "EndTime": 1632223766.1576252, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6505871855083265, "count": 1, "min": 0.6505871855083265, "max": 0.6505871855083265}}}
#
# #metrics {"StartTime": 1632223766.1576762, "EndTime": 1632223766.1576905, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6483191785310444, "count": 1, "min": 0.6483191785310444, "max": 0.6483191785310444}}}
#
# #metrics {"StartTime": 1632223766.1577446, "EndTime": 1632223766.1577613, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6526740064119038, "count": 1, "min": 0.6526740064119038, "max": 0.6526740064119038}}}
#
# #metrics {"StartTime": 1632223766.1578104, "EndTime": 1632223766.1578262, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6446643395674856, "count": 1, "min": 0.6446643395674856, "max": 0.6446643395674856}}}
#
# #metrics {"StartTime": 1632223766.1578727, "EndTime": 1632223766.157888, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6347046685469778, "count": 1, "min": 0.6347046685469778, "max": 0.6347046685469778}}}
#
# #metrics {"StartTime": 1632223766.1579378, "EndTime": 1632223766.1579535, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6332199433979235, "count": 1, "min": 0.6332199433979235, "max": 0.6332199433979235}}}
#
# #metrics {"StartTime": 1632223766.158001, "EndTime": 1632223766.1580162, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6355781763980263, "count": 1, "min": 0.6355781763980263, "max": 0.6355781763980263}}}
#
# #metrics {"StartTime": 1632223766.1580684, "EndTime": 1632223766.158083, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6792383222078022, "count": 1, "min": 0.6792383222078022, "max": 0.6792383222078022}}}
#
# #metrics {"StartTime": 1632223766.1581361, "EndTime": 1632223766.1581516, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6820694371273643, "count": 1, "min": 0.6820694371273643, "max": 0.6820694371273643}}}
#
# #metrics {"StartTime": 1632223766.1582034, "EndTime": 1632223766.1582181, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6812366855019018, "count": 1, "min": 0.6812366855019018, "max": 0.6812366855019018}}}
#
# #metrics {"StartTime": 1632223766.1582704, "EndTime": 1632223766.1582859, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6801348025673314, "count": 1, "min": 0.6801348025673314, "max": 0.6801348025673314}}}
#
# #metrics {"StartTime": 1632223766.1583197, "EndTime": 1632223766.1583335, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6809083308169717, "count": 1, "min": 0.6809083308169717, "max": 0.6809083308169717}}}
#
# #metrics {"StartTime": 1632223766.1583724, "EndTime": 1632223766.158387, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6878971758390727, "count": 1, "min": 0.6878971758390727, "max": 0.6878971758390727}}}
#
# #metrics {"StartTime": 1632223766.158437, "EndTime": 1632223766.1584527, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6809811802914268, "count": 1, "min": 0.6809811802914268, "max": 0.6809811802914268}}}
#
# #metrics {"StartTime": 1632223766.1584945, "EndTime": 1632223766.1585097, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6881548975894326, "count": 1, "min": 0.6881548975894326, "max": 0.6881548975894326}}}
#
# [09/21/2021 11:29:26 INFO 139736075499328] #quality_metric: host=algo-1, epoch=0, train binary_classification_weighted_cross_entropy_objective <loss>=0.6242944745515522
# [09/21/2021 11:29:26 INFO 139736075499328] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_weighted_cross_entropy_objective, value=0.6089744435360557
# [09/21/2021 11:29:26 INFO 139736075499328] Epoch 0: Loss improved. Updating best model
# [09/21/2021 11:29:26 INFO 139736075499328] Saving model for epoch: 0
# [09/21/2021 11:29:26 INFO 139736075499328] Saved checkpoint to "/tmp/tmpx3x24iqc/mx-mod-0000.params"
# [09/21/2021 11:29:26 INFO 139736075499328] #progress_metric: host=algo-1, completed 6.666666666666667 % of epochs
# #metrics {"StartTime": 1632223763.5502691, "EndTime": 1632223766.1733148, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 88277.0, "count": 1, "min": 88277, "max": 88277}, "Total Batches Seen": {"sum": 89.0, "count": 1, "min": 89, "max": 89}, "Max Records Seen Between Resets": {"sum": 76277.0, "count": 1, "min": 76277, "max": 76277}, "Max Batches Seen Between Resets": {"sum": 77.0, "count": 1, "min": 77, "max": 77}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 76277.0, "count": 1, "min": 76277, "max": 76277}, "Number of Batches Since Last Reset": {"sum": 77.0, "count": 1, "min": 77, "max": 77}}}
#
# [09/21/2021 11:29:26 INFO 139736075499328] #throughput_metric: host=algo-1, train throughput=29078.13259538451 records/second
# [2021-09-21 11:29:29.503] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 3329, "num_examples": 77, "num_bytes": 10983888}
# #metrics {"StartTime": 1632223769.5037587, "EndTime": 1632223769.503909, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5939567284835012, "count": 1, "min": 0.5939567284835012, "max": 0.5939567284835012}}}
#
# #metrics {"StartTime": 1632223769.504017, "EndTime": 1632223769.5040388, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5908401135896382, "count": 1, "min": 0.5908401135896382, "max": 0.5908401135896382}}}
#
# #metrics {"StartTime": 1632223769.5041883, "EndTime": 1632223769.5042112, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5900450588025545, "count": 1, "min": 0.5900450588025545, "max": 0.5900450588025545}}}
#
# #metrics {"StartTime": 1632223769.5043805, "EndTime": 1632223769.5044022, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5939308821025647, "count": 1, "min": 0.5939308821025647, "max": 0.5939308821025647}}}
#
# #metrics {"StartTime": 1632223769.5045736, "EndTime": 1632223769.5045965, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.7567748597797594, "count": 1, "min": 0.7567748597797594, "max": 0.7567748597797594}}}
#
# #metrics {"StartTime": 1632223769.5048258, "EndTime": 1632223769.5048444, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6033235240735506, "count": 1, "min": 0.6033235240735506, "max": 0.6033235240735506}}}
#
# #metrics {"StartTime": 1632223769.5048943, "EndTime": 1632223769.504909, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6374590662906044, "count": 1, "min": 0.6374590662906044, "max": 0.6374590662906044}}}
#
# #metrics {"StartTime": 1632223769.5049565, "EndTime": 1632223769.5049706, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.8101865242405941, "count": 1, "min": 0.8101865242405941, "max": 0.8101865242405941}}}
#
# #metrics {"StartTime": 1632223769.505012, "EndTime": 1632223769.5050242, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5905413224069695, "count": 1, "min": 0.5905413224069695, "max": 0.5905413224069695}}}
#
# #metrics {"StartTime": 1632223769.5050616, "EndTime": 1632223769.5050728, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.590393529390034, "count": 1, "min": 0.590393529390034, "max": 0.590393529390034}}}
#
# #metrics {"StartTime": 1632223769.5051389, "EndTime": 1632223769.5051548, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5894897790206106, "count": 1, "min": 0.5894897790206106, "max": 0.5894897790206106}}}
#
# #metrics {"StartTime": 1632223769.5052059, "EndTime": 1632223769.5052226, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5940036966424239, "count": 1, "min": 0.5940036966424239, "max": 0.5940036966424239}}}
#
# #metrics {"StartTime": 1632223769.5052752, "EndTime": 1632223769.5052912, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.7441588572451943, "count": 1, "min": 0.7441588572451943, "max": 0.7441588572451943}}}
#
# #metrics {"StartTime": 1632223769.505338, "EndTime": 1632223769.5053532, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6229684693185906, "count": 1, "min": 0.6229684693185906, "max": 0.6229684693185906}}}
#
# #metrics {"StartTime": 1632223769.5054002, "EndTime": 1632223769.505416, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6129319723028885, "count": 1, "min": 0.6129319723028885, "max": 0.6129319723028885}}}
#
# #metrics {"StartTime": 1632223769.5054643, "EndTime": 1632223769.5054803, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.7437311003835577, "count": 1, "min": 0.7437311003835577, "max": 0.7437311003835577}}}
#
# #metrics {"StartTime": 1632223769.505529, "EndTime": 1632223769.505544, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6410977293315687, "count": 1, "min": 0.6410977293315687, "max": 0.6410977293315687}}}
#
# #metrics {"StartTime": 1632223769.5055902, "EndTime": 1632223769.5056052, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6409164115504214, "count": 1, "min": 0.6409164115504214, "max": 0.6409164115504214}}}
#
# #metrics {"StartTime": 1632223769.505655, "EndTime": 1632223769.5056703, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6413027946070621, "count": 1, "min": 0.6413027946070621, "max": 0.6413027946070621}}}
#
# #metrics {"StartTime": 1632223769.5057204, "EndTime": 1632223769.5057364, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.641341403358861, "count": 1, "min": 0.641341403358861, "max": 0.641341403358861}}}
#
# #metrics {"StartTime": 1632223769.5057867, "EndTime": 1632223769.5058022, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6382756468120374, "count": 1, "min": 0.6382756468120374, "max": 0.6382756468120374}}}
#
# #metrics {"StartTime": 1632223769.5058477, "EndTime": 1632223769.5058625, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6355378329628393, "count": 1, "min": 0.6355378329628393, "max": 0.6355378329628393}}}
#
# #metrics {"StartTime": 1632223769.5059092, "EndTime": 1632223769.505924, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6365973269813939, "count": 1, "min": 0.6365973269813939, "max": 0.6365973269813939}}}
#
# #metrics {"StartTime": 1632223769.505972, "EndTime": 1632223769.5059862, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6380864378276624, "count": 1, "min": 0.6380864378276624, "max": 0.6380864378276624}}}
#
# #metrics {"StartTime": 1632223769.5060341, "EndTime": 1632223769.5060494, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6795913029720909, "count": 1, "min": 0.6795913029720909, "max": 0.6795913029720909}}}
#
# #metrics {"StartTime": 1632223769.506098, "EndTime": 1632223769.5061138, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6794715624357525, "count": 1, "min": 0.6794715624357525, "max": 0.6794715624357525}}}
#
# #metrics {"StartTime": 1632223769.5061634, "EndTime": 1632223769.5061789, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6794621911299856, "count": 1, "min": 0.6794621911299856, "max": 0.6794621911299856}}}
#
# #metrics {"StartTime": 1632223769.506226, "EndTime": 1632223769.5062416, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6790589053505346, "count": 1, "min": 0.6790589053505346, "max": 0.6790589053505346}}}
#
# #metrics {"StartTime": 1632223769.5062904, "EndTime": 1632223769.5063066, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6806857299804687, "count": 1, "min": 0.6806857299804687, "max": 0.6806857299804687}}}
#
# #metrics {"StartTime": 1632223769.5063524, "EndTime": 1632223769.506368, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6845758948075144, "count": 1, "min": 0.6845758948075144, "max": 0.6845758948075144}}}
#
# #metrics {"StartTime": 1632223769.5064178, "EndTime": 1632223769.5064332, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6806176549008018, "count": 1, "min": 0.6806176549008018, "max": 0.6806176549008018}}}
#
# #metrics {"StartTime": 1632223769.5064836, "EndTime": 1632223769.5064995, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6850633689478824, "count": 1, "min": 0.6850633689478824, "max": 0.6850633689478824}}}
#
# [09/21/2021 11:29:29 INFO 139736075499328] #quality_metric: host=algo-1, epoch=1, train binary_classification_weighted_cross_entropy_objective <loss>=0.5939567284835012
# [09/21/2021 11:29:29 INFO 139736075499328] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_weighted_cross_entropy_objective, value=0.5894897790206106
# [09/21/2021 11:29:29 INFO 139736075499328] Epoch 1: Loss improved. Updating best model
# [09/21/2021 11:29:29 INFO 139736075499328] Saving model for epoch: 1
# [09/21/2021 11:29:29 INFO 139736075499328] Saved checkpoint to "/tmp/tmpbs0eh1hr/mx-mod-0000.params"
# [09/21/2021 11:29:29 INFO 139736075499328] #progress_metric: host=algo-1, completed 13.333333333333334 % of epochs
# #metrics {"StartTime": 1632223766.1740718, "EndTime": 1632223769.5203943, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 164554.0, "count": 1, "min": 164554, "max": 164554}, "Total Batches Seen": {"sum": 166.0, "count": 1, "min": 166, "max": 166}, "Max Records Seen Between Resets": {"sum": 76277.0, "count": 1, "min": 76277, "max": 76277}, "Max Batches Seen Between Resets": {"sum": 77.0, "count": 1, "min": 77, "max": 77}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 76277.0, "count": 1, "min": 76277, "max": 76277}, "Number of Batches Since Last Reset": {"sum": 77.0, "count": 1, "min": 77, "max": 77}}}
#
# [09/21/2021 11:29:29 INFO 139736075499328] #throughput_metric: host=algo-1, train throughput=22793.491768189702 records/second
#
# 2021-09-21 11:29:37 Training - Training image download completed. Training in progress.[2021-09-21 11:29:32.153] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 7, "duration": 2631, "num_examples": 77, "num_bytes": 10983888}
# #metrics {"StartTime": 1632223772.1532054, "EndTime": 1632223772.1532974, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 0}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5906515470805921, "count": 1, "min": 0.5906515470805921, "max": 0.5906515470805921}}}
#
# #metrics {"StartTime": 1632223772.153401, "EndTime": 1632223772.1534162, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 1}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5885496131495426, "count": 1, "min": 0.5885496131495426, "max": 0.5885496131495426}}}
#
# #metrics {"StartTime": 1632223772.1534495, "EndTime": 1632223772.1534631, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 2}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5865970695897152, "count": 1, "min": 0.5865970695897152, "max": 0.5865970695897152}}}
#
# #metrics {"StartTime": 1632223772.1535027, "EndTime": 1632223772.1535122, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 3}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5912929751747533, "count": 1, "min": 0.5912929751747533, "max": 0.5912929751747533}}}
#
# #metrics {"StartTime": 1632223772.1535416, "EndTime": 1632223772.1535542, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 4}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.7974147322805304, "count": 1, "min": 0.7974147322805304, "max": 0.7974147322805304}}}
#
# #metrics {"StartTime": 1632223772.1536093, "EndTime": 1632223772.153625, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 5}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6412055190236945, "count": 1, "min": 0.6412055190236945, "max": 0.6412055190236945}}}
#
# #metrics {"StartTime": 1632223772.1536827, "EndTime": 1632223772.1536999, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 6}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.642164023148386, "count": 1, "min": 0.642164023148386, "max": 0.642164023148386}}}
#
# #metrics {"StartTime": 1632223772.1537478, "EndTime": 1632223772.153762, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 7}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.809399459035773, "count": 1, "min": 0.809399459035773, "max": 0.809399459035773}}}
#
# #metrics {"StartTime": 1632223772.1538198, "EndTime": 1632223772.1538363, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 8}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5875619956568667, "count": 1, "min": 0.5875619956568667, "max": 0.5875619956568667}}}
#
# #metrics {"StartTime": 1632223772.1538944, "EndTime": 1632223772.153911, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 9}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5868011217619243, "count": 1, "min": 0.5868011217619243, "max": 0.5868011217619243}}}
#
# #metrics {"StartTime": 1632223772.153972, "EndTime": 1632223772.1539876, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 10}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5865660287957443, "count": 1, "min": 0.5865660287957443, "max": 0.5865660287957443}}}
#
# #metrics {"StartTime": 1632223772.1540377, "EndTime": 1632223772.1540534, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 11}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5912856878983347, "count": 1, "min": 0.5912856878983347, "max": 0.5912856878983347}}}
#
# #metrics {"StartTime": 1632223772.1541011, "EndTime": 1632223772.1541154, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 12}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.7245620149311266, "count": 1, "min": 0.7245620149311266, "max": 0.7245620149311266}}}
#
# #metrics {"StartTime": 1632223772.1541588, "EndTime": 1632223772.1541684, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 13}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.7159848966096577, "count": 1, "min": 0.7159848966096577, "max": 0.7159848966096577}}}
#
# #metrics {"StartTime": 1632223772.1542063, "EndTime": 1632223772.1542206, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 14}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.7282527004041169, "count": 1, "min": 0.7282527004041169, "max": 0.7282527004041169}}}
#
# #metrics {"StartTime": 1632223772.15427, "EndTime": 1632223772.1542866, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 15}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.858871064035516, "count": 1, "min": 0.858871064035516, "max": 0.858871064035516}}}
#
# #metrics {"StartTime": 1632223772.1543403, "EndTime": 1632223772.1543562, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 16}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.641279461509303, "count": 1, "min": 0.641279461509303, "max": 0.641279461509303}}}
#
# #metrics {"StartTime": 1632223772.154403, "EndTime": 1632223772.154418, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 17}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.640952198229338, "count": 1, "min": 0.640952198229338, "max": 0.640952198229338}}}
#
# #metrics {"StartTime": 1632223772.1544664, "EndTime": 1632223772.154482, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 18}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6413503241288034, "count": 1, "min": 0.6413503241288034, "max": 0.6413503241288034}}}
#
# #metrics {"StartTime": 1632223772.1545162, "EndTime": 1632223772.1545305, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 19}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6411138779489618, "count": 1, "min": 0.6411138779489618, "max": 0.6411138779489618}}}
#
# #metrics {"StartTime": 1632223772.15458, "EndTime": 1632223772.154596, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 20}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6377946648848685, "count": 1, "min": 0.6377946648848685, "max": 0.6377946648848685}}}
#
# #metrics {"StartTime": 1632223772.1546452, "EndTime": 1632223772.154661, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 21}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6365458815725226, "count": 1, "min": 0.6365458815725226, "max": 0.6365458815725226}}}
#
# #metrics {"StartTime": 1632223772.1546977, "EndTime": 1632223772.154711, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 22}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6411071263363487, "count": 1, "min": 0.6411071263363487, "max": 0.6411071263363487}}}
#
# #metrics {"StartTime": 1632223772.154761, "EndTime": 1632223772.1547768, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 23}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6398671417236328, "count": 1, "min": 0.6398671417236328, "max": 0.6398671417236328}}}
#
# #metrics {"StartTime": 1632223772.1548157, "EndTime": 1632223772.1548302, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 24}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6799680914627878, "count": 1, "min": 0.6799680914627878, "max": 0.6799680914627878}}}
#
# #metrics {"StartTime": 1632223772.1548696, "EndTime": 1632223772.1548834, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 25}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6792600732100638, "count": 1, "min": 0.6792600732100638, "max": 0.6792600732100638}}}
#
# #metrics {"StartTime": 1632223772.1549296, "EndTime": 1632223772.1549447, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 26}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6800816481740851, "count": 1, "min": 0.6800816481740851, "max": 0.6800816481740851}}}
#
# #metrics {"StartTime": 1632223772.1549928, "EndTime": 1632223772.1550086, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 27}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6789187180368523, "count": 1, "min": 0.6789187180368523, "max": 0.6789187180368523}}}
#
# #metrics {"StartTime": 1632223772.1550615, "EndTime": 1632223772.155077, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 28}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6857348142925062, "count": 1, "min": 0.6857348142925062, "max": 0.6857348142925062}}}
#
# #metrics {"StartTime": 1632223772.1551268, "EndTime": 1632223772.1551423, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 29}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6840640274850945, "count": 1, "min": 0.6840640274850945, "max": 0.6840640274850945}}}
#
# #metrics {"StartTime": 1632223772.1551898, "EndTime": 1632223772.1552048, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 30}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6855375470613179, "count": 1, "min": 0.6855375470613179, "max": 0.6855375470613179}}}
#
# #metrics {"StartTime": 1632223772.1552498, "EndTime": 1632223772.1552656, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 31}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6844946128443667, "count": 1, "min": 0.6844946128443667, "max": 0.6844946128443667}}}
#
# [09/21/2021 11:29:32 INFO 139736075499328] #quality_metric: host=algo-1, epoch=2, train binary_classification_weighted_cross_entropy_objective <loss>=0.5906515470805921
# [09/21/2021 11:29:32 INFO 139736075499328] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_weighted_cross_entropy_objective, value=0.5865660287957443
# [09/21/2021 11:29:32 INFO 139736075499328] Epoch 2: Loss improved. Updating best model
# [09/21/2021 11:29:32 INFO 139736075499328] Saving model for epoch: 2
# [09/21/2021 11:29:32 INFO 139736075499328] Saved checkpoint to "/tmp/tmp_d5h5y8q/mx-mod-0000.params"
# [09/21/2021 11:29:32 INFO 139736075499328] #progress_metric: host=algo-1, completed 20.0 % of epochs
# #metrics {"StartTime": 1632223769.5212069, "EndTime": 1632223772.1649933, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 240831.0, "count": 1, "min": 240831, "max": 240831}, "Total Batches Seen": {"sum": 243.0, "count": 1, "min": 243, "max": 243}, "Max Records Seen Between Resets": {"sum": 76277.0, "count": 1, "min": 76277, "max": 76277}, "Max Batches Seen Between Resets": {"sum": 77.0, "count": 1, "min": 77, "max": 77}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 76277.0, "count": 1, "min": 76277, "max": 76277}, "Number of Batches Since Last Reset": {"sum": 77.0, "count": 1, "min": 77, "max": 77}}}
#
# [09/21/2021 11:29:32 INFO 139736075499328] #throughput_metric: host=algo-1, train throughput=28849.908571282227 records/second
# [2021-09-21 11:29:35.074] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 9, "duration": 2908, "num_examples": 77, "num_bytes": 10983888}
# #metrics {"StartTime": 1632223775.074324, "EndTime": 1632223775.0744185, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 0}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5859114934017784, "count": 1, "min": 0.5859114934017784, "max": 0.5859114934017784}}}
#
# #metrics {"StartTime": 1632223775.0745144, "EndTime": 1632223775.0745354, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 1}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5879970012464021, "count": 1, "min": 0.5879970012464021, "max": 0.5879970012464021}}}
#
# #metrics {"StartTime": 1632223775.0745895, "EndTime": 1632223775.0746017, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 2}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5847868676436575, "count": 1, "min": 0.5847868676436575, "max": 0.5847868676436575}}}
#
# ...
#
# #metrics {"StartTime": 1632223788.6174607, "EndTime": 1632223788.617478, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 3}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5859067571539628, "count": 1, "min": 0.5859067571539628, "max": 0.5859067571539628}}}
#
# #metrics {"StartTime": 1632223788.6175275, "EndTime": 1632223788.617544, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 4}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.8332773887232731, "count": 1, "min": 0.8332773887232731, "max": 0.8332773887232731}}}
#
# #metrics {"StartTime": 1632223788.6175933, "EndTime": 1632223788.6176093, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 5}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.9316279521741365, "count": 1, "min": 0.9316279521741365, "max": 0.9316279521741365}}}
#
# #metrics {"StartTime": 1632223788.617653, "EndTime": 1632223788.617668, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 6}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6456616640592876, "count": 1, "min": 0.6456616640592876, "max": 0.6456616640592876}}}
#
# #metrics {"StartTime": 1632223788.6177156, "EndTime": 1632223788.617731, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 7}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.278568787424188, "count": 1, "min": 1.278568787424188, "max": 1.278568787424188}}}
#
# #metrics {"StartTime": 1632223788.6177824, "EndTime": 1632223788.6177979, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 8}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5825641820807206, "count": 1, "min": 0.5825641820807206, "max": 0.5825641820807206}}}
#
# #metrics {"StartTime": 1632223788.6178384, "EndTime": 1632223788.6178539, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 9}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5821026446693822, "count": 1, "min": 0.5821026446693822, "max": 0.5821026446693822}}}
#
# #metrics {"StartTime": 1632223788.6179047, "EndTime": 1632223788.617921, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 10}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5825651546277498, "count": 1, "min": 0.5825651546277498, "max": 0.5825651546277498}}}
#
# #metrics {"StartTime": 1632223788.6179676, "EndTime": 1632223788.6179826, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 11}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5832823594745836, "count": 1, "min": 0.5832823594745836, "max": 0.5832823594745836}}}
#
# #metrics {"StartTime": 1632223788.6180332, "EndTime": 1632223788.618048, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 12}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6113449317530582, "count": 1, "min": 0.6113449317530582, "max": 0.6113449317530582}}}
#
# #metrics {"StartTime": 1632223788.6180966, "EndTime": 1632223788.6181104, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 13}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6095014174611945, "count": 1, "min": 0.6095014174611945, "max": 0.6095014174611945}}}
#
# #metrics {"StartTime": 1632223788.6181555, "EndTime": 1632223788.6181707, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 14}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6174756361308851, "count": 1, "min": 0.6174756361308851, "max": 0.6174756361308851}}}
#
# #metrics {"StartTime": 1632223788.618227, "EndTime": 1632223788.6182427, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 15}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.773840008384303, "count": 1, "min": 0.773840008384303, "max": 0.773840008384303}}}
#
# #metrics {"StartTime": 1632223788.6182942, "EndTime": 1632223788.6183107, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 16}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6416203284012644, "count": 1, "min": 0.6416203284012644, "max": 0.6416203284012644}}}
#
# #metrics {"StartTime": 1632223788.6183584, "EndTime": 1632223788.6183732, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 17}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6408212464985095, "count": 1, "min": 0.6408212464985095, "max": 0.6408212464985095}}}
#
# #metrics {"StartTime": 1632223788.6184194, "EndTime": 1632223788.6184351, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 18}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6416142963610197, "count": 1, "min": 0.6416142963610197, "max": 0.6416142963610197}}}
#
# #metrics {"StartTime": 1632223788.6184778, "EndTime": 1632223788.6184928, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 19}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6408561875192743, "count": 1, "min": 0.6408561875192743, "max": 0.6408561875192743}}}
#
# #metrics {"StartTime": 1632223788.6185405, "EndTime": 1632223788.618556, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 20}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6342561107434724, "count": 1, "min": 0.6342561107434724, "max": 0.6342561107434724}}}
#
# #metrics {"StartTime": 1632223788.6186059, "EndTime": 1632223788.618622, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 21}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.640622538516396, "count": 1, "min": 0.640622538516396, "max": 0.640622538516396}}}
#
# #metrics {"StartTime": 1632223788.6186683, "EndTime": 1632223788.6186829, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 22}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6344676770662007, "count": 1, "min": 0.6344676770662007, "max": 0.6344676770662007}}}
#
# #metrics {"StartTime": 1632223788.6187315, "EndTime": 1632223788.6187477, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 23}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6400389058966386, "count": 1, "min": 0.6400389058966386, "max": 0.6400389058966386}}}
#
# #metrics {"StartTime": 1632223788.6188004, "EndTime": 1632223788.618817, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 24}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6806664396587171, "count": 1, "min": 0.6806664396587171, "max": 0.6806664396587171}}}
#
# #metrics {"StartTime": 1632223788.6188693, "EndTime": 1632223788.6188846, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 25}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6790446745219983, "count": 1, "min": 0.6790446745219983, "max": 0.6790446745219983}}}
#
# #metrics {"StartTime": 1632223788.6189296, "EndTime": 1632223788.6189451, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 26}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6808549820749383, "count": 1, "min": 0.6808549820749383, "max": 0.6808549820749383}}}
#
# #metrics {"StartTime": 1632223788.6189923, "EndTime": 1632223788.6190088, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 27}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6789518175627056, "count": 1, "min": 0.6789518175627056, "max": 0.6789518175627056}}}
#
# #metrics {"StartTime": 1632223788.6190605, "EndTime": 1632223788.6190798, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 28}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6976417678029914, "count": 1, "min": 0.6976417678029914, "max": 0.6976417678029914}}}
#
# #metrics {"StartTime": 1632223788.61914, "EndTime": 1632223788.6191568, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 29}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6863999746222245, "count": 1, "min": 0.6863999746222245, "max": 0.6863999746222245}}}
#
# #metrics {"StartTime": 1632223788.6192126, "EndTime": 1632223788.619229, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 30}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6978763251053659, "count": 1, "min": 0.6978763251053659, "max": 0.6978763251053659}}}
#
# #metrics {"StartTime": 1632223788.6192803, "EndTime": 1632223788.6192963, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 31}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6865632878353721, "count": 1, "min": 0.6865632878353721, "max": 0.6865632878353721}}}
#
# [09/21/2021 11:29:48 INFO 139736075499328] #quality_metric: host=algo-1, epoch=8, train binary_classification_weighted_cross_entropy_objective <loss>=0.5852807946456106
# [09/21/2021 11:29:48 INFO 139736075499328] #early_stopping_criteria_metric: host=algo-1, epoch=8, criteria=binary_classification_weighted_cross_entropy_objective, value=0.5821026446693822
# [09/21/2021 11:29:48 INFO 139736075499328] Saving model for epoch: 8
# [09/21/2021 11:29:48 INFO 139736075499328] Saved checkpoint to "/tmp/tmpos_vl11q/mx-mod-0000.params"
# [09/21/2021 11:29:48 INFO 139736075499328] Early stop condition met. Stopping training.
# [09/21/2021 11:29:48 INFO 139736075499328] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"StartTime": 1632223785.7809453, "EndTime": 1632223788.6290472, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 698493.0, "count": 1, "min": 698493, "max": 698493}, "Total Batches Seen": {"sum": 705.0, "count": 1, "min": 705, "max": 705}, "Max Records Seen Between Resets": {"sum": 76277.0, "count": 1, "min": 76277, "max": 76277}, "Max Batches Seen Between Resets": {"sum": 77.0, "count": 1, "min": 77, "max": 77}, "Reset Count": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Number of Records Since Last Reset": {"sum": 76277.0, "count": 1, "min": 76277, "max": 76277}, "Number of Batches Since Last Reset": {"sum": 77.0, "count": 1, "min": 77, "max": 77}}}
#
# [09/21/2021 11:29:48 INFO 139736075499328] #throughput_metric: host=algo-1, train throughput=26780.149843782634 records/second
# [09/21/2021 11:29:48 WARNING 139736075499328] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [09/21/2021 11:29:48 WARNING 139736075499328] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2021-09-21 11:29:48.633] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 21, "duration": 3, "num_examples": 1, "num_bytes": 144000}
# [2021-09-21 11:29:48.882] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 24, "duration": 245, "num_examples": 77, "num_bytes": 10983888}
# [2021-09-21 11:29:49.207] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 26, "duration": 286, "num_examples": 77, "num_bytes": 10983888}
# [09/21/2021 11:29:49 INFO 139736075499328] #train_score (algo-1) : ('binary_classification_weighted_cross_entropy_objective', 0.5863935440899463)
# [09/21/2021 11:29:49 INFO 139736075499328] #train_score (algo-1) : ('binary_classification_accuracy', 0.6796281972285224)
# [09/21/2021 11:29:49 INFO 139736075499328] #train_score (algo-1) : ('binary_f_1.000', 0.7608880713118523)
# [09/21/2021 11:29:49 INFO 139736075499328] #train_score (algo-1) : ('precision', 0.658051959042058)
# [09/21/2021 11:29:49 INFO 139736075499328] #train_score (algo-1) : ('recall', 0.9018184348471494)
# [09/21/2021 11:29:49 INFO 139736075499328] #train_score (algo-1) : ('roc_auc_score', 0.7387486220332525)
# [09/21/2021 11:29:49 INFO 139736075499328] #quality_metric: host=algo-1, train binary_classification_weighted_cross_entropy_objective <loss>=0.5863935440899463
# [09/21/2021 11:29:49 INFO 139736075499328] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.6796281972285224
# [09/21/2021 11:29:49 INFO 139736075499328] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.7608880713118523
# [09/21/2021 11:29:49 INFO 139736075499328] #quality_metric: host=algo-1, train precision <score>=0.658051959042058
# [09/21/2021 11:29:49 INFO 139736075499328] #quality_metric: host=algo-1, train recall <score>=0.9018184348471494
# [09/21/2021 11:29:49 INFO 139736075499328] #quality_metric: host=algo-1, train roc_auc_score <score>=0.7387486220332525
# [09/21/2021 11:29:49 INFO 139736075499328] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.005, "wd": 0.01, "l1": 0.0, "lr_scheduler_step": 10, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 1e-05}
# [09/21/2021 11:29:49 INFO 139736075499328] Saved checkpoint to "/tmp/tmpy2w6b97j/mx-mod-0000.params"
# [09/21/2021 11:29:49 INFO 139736075499328] Test data is not provided.
# #metrics {"StartTime": 1632223763.2503128, "EndTime": 1632223789.2427313, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 296.5106964111328, "count": 1, "min": 296.5106964111328, "max": 296.5106964111328}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 5.534172058105469, "count": 9, "min": 0.19025802612304688, "max": 1.2094974517822266}, "update.time": {"sum": 25042.853355407715, "count": 9, "min": 2560.50181388855, "max": 3343.351364135742}, "finalize.time": {"sum": 604.1703224182129, "count": 1, "min": 604.1703224182129, "max": 604.1703224182129}, "setuptime": {"sum": 22.351503372192383, "count": 1, "min": 22.351503372192383, "max": 22.351503372192383}, "totaltime": {"sum": 26199.499130249023, "count": 1, "min": 26199.499130249023, "max": 26199.499130249023}}}
#
#
# 2021-09-21 11:30:17 Uploading - Uploading generated training model
# 2021-09-21 11:30:17 Completed - Training job completed
# ProfilerReport-1632223546: NoIssuesFound
# Training seconds: 79
# Billable seconds: 79
# CPU times: user 723 ms, sys: 64.3 ms, total: 788 ms
# Wall time: 4min 42s

# %% [markdown]
# ### EXERCISE: Deploy and evaluate the balanced estimator
#
# Deploy the balanced predictor and evaluate it. Do the results match with your expectations?

# %%
# %%time 
# deploy and create a predictor
balanced_predictor = linear_balanced.deploy(initial_instance_count=1, instance_type='ml.t2.medium')
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# ------------!CPU times: user 281 ms, sys: 12.6 ms, total: 293 ms
# Wall time: 6min 3s

# %%
print('Metrics for balanced, LinearLearner.\n')

# get metrics for balanced predictor
metrics = evaluate(balanced_predictor, 
                   features.values.astype('float32'), 
                   targets.values.flatten(), 
                   verbose=True)
# Out:
# Metrics for balanced, LinearLearner.
#
# prediction (col)    0.0    1.0
# actual (row)
# 0                 12959  20204
# 1                  4233  38881
#
# Recall:     0.902
# Precision:  0.658
# Accuracy:   0.680

# %% [markdown]
# ## Delete the endpoint
#
# When you're done evaluating a model, you should delete the endpoint.

# %%
sagemaker_session.delete_endpoint(endpoint_name=balanced_predictor.endpoint_name)

# %%
sagemaker_session.delete_endpoint(endpoint_name='linear-learner-2021-09-21-11-32-07-490')

# %%
# delete the predictor endpoint 
delete_endpoint(balanced_predictor)
# Out:
# Already deleted: linear-learner-2021-09-21-11-45-05-238
